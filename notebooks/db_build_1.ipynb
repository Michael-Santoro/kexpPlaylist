# %%
import google.auth

credentials, project_id = google.auth.default()

# install dependencies
# pip install cloud-sql-python-connector["pymysql"] SQLAlchemy==2.0.7

import sys
if '..' not in sys.path:
    sys.path.append('..')

from scripts.utils import openfile
from scripts.utils import Hosts, Plays, Programs, Shows, Timeslots


from google.cloud.sql.connector import Connector

import sqlalchemy
from sqlalchemy import MetaData
from sqlalchemy.orm import sessionmaker
from sqlalchemy.sql.expression import func

from creds import user

import requests
import pandas as pd

# %%
# initialize parameters
INSTANCE_CONNECTION_NAME = user['INSTANCE_CONNECTION_NAME']# i.e demo-project:us-central1:demo-instance
print(f"Your instance connection name is: {INSTANCE_CONNECTION_NAME}")
DB_USER = user['DB_USER']
DB_PASS = user['DB_PASS']
DB_NAME = user['DB_NAME']


root_path = user['root_path']
# Out:
# Your instance connection name is: kexp-explore:us-central1:kexp-sandbox

# %%
# initialize Connector object
connector = Connector()

# function to return the database connection object
def getconn():
    conn = connector.connect(
        INSTANCE_CONNECTION_NAME,
        "pymysql",
        user=DB_USER,
        password=DB_PASS,
        db=DB_NAME
    )
    return conn

# create connection pool with 'creator' argument to our connection object function
pool = sqlalchemy.create_engine(
    "mysql+pymysql://",
    creator=getconn,
)

engine = pool

# %%
r = requests.get('https://api.kexp.org/v2/')
r.status_code

urls = r.json()
urls
# Out:
# {'hosts': 'https://api.kexp.org/v2/hosts/',
#  'programs': 'https://api.kexp.org/v2/programs/',
#  'shows': 'https://api.kexp.org/v2/shows/',
#  'plays': 'https://api.kexp.org/v2/plays/',
#  'timeslots': 'https://api.kexp.org/v2/timeslots/'}

# %% [markdown]
# ### Programs Populate

# %%
programs = requests.get(urls['programs'])
programs_json=programs.json()
print(f"Total Entries: {programs_json['count']}")
# Out:
# Total Entries: 40

# %%
programs_json
# Out:
# {'count': 40,
#  'next': 'https://api.kexp.org/v2/programs/?limit=20&offset=20',
#  'previous': None,
#  'results': [{'id': 26,
#    'uri': 'https://api.kexp.org/v2/programs/26/',
#    'name': '90.TEEN',
#    'description': 'Rock,Eclectic,Variety Mix',
#    'tags': 'Rock,Eclectic,Variety Mix',
#    'is_active': True},
#   {'id': 38,
#    'uri': 'https://api.kexp.org/v2/programs/38/',
#    'name': 'Astral Plane',
#    'description': '',
#    'tags': 'Rock,Eclectic,Psychedelic',
#    'is_active': True},
#   {'id': 1,
#    'uri': 'https://api.kexp.org/v2/programs/1/',
#    'name': 'Audioasis',
#    'description': "Audioasis is KEXP's long-running Northwest music show hosted by Sharlese Metcalf. Past hosts have included Jonathen Poneman, Jason Hughes, Scott Vanderpool, Stevie Zoom, Sean Nelson and Hannah Levin. John Richards helps produce the show. Audioasis delivers three hours of local and live bands from all areas and genres of the Northwest. On Audioasis, you'll hear the new, the old, the demos, the vinyl, and the future of music. Every first Saturday of the month you can catch Audioasis out in the city LIVE! Tune in Saturday from 6-9 PM.",
#    'tags': 'Rock,Eclectic,Pacific Northwest',
#    'is_active': True},
#   {'id': 27,
#    'uri': 'https://api.kexp.org/v2/programs/27/',
#    'name': 'Best Ambiance',
#    'description': 'Went off the air in 2011.',
#    'tags': 'African,World',
#    'is_active': False},
#   {'id': 33,
#    'uri': 'https://api.kexp.org/v2/programs/33/',
#    'name': 'Drive Time',
#    'description': '',
#    'tags': 'Rock,Eclectic,Variety Mix',
#    'is_active': True},
#   {'id': 32,
#    'uri': 'https://api.kexp.org/v2/programs/32/',
#    'name': 'Early',
#    'description': '',
#    'tags': 'Rock,Eclectic,Variety Mix',
#    'is_active': True},
#   {'id': 37,
#    'uri': 'https://api.kexp.org/v2/programs/37/',
#    'name': 'Eastern Echoes',
#    'description': '',
#    'tags': 'Eclectic,Variety,World',
#    'is_active': True},
#   {'id': 2,
#    'uri': 'https://api.kexp.org/v2/programs/2/',
#    'name': 'El Sonido',
#    'description': "El Sonido is a three hour trip around the diverse world of Latin music and culture from South, Central and North America, as well as Spain and the rest of the globe. \\n\\nThe focus is on new music and the growing Latin alternative scene, but traditional styles, both old and new are also regularly spotlighted. There's tons of fresh contemporary flavors to enjoy from hip-hop, nu-cumbia, indie-rock, reggaeton and dance punk to indie-folk, tropical bass, reggae, funk and more. Plus there’s an endless number of traditional styles too, you’ll hear bachata, tango, salsa, flamenco, norteño and dozens of others. \\n\\nMusicians and DJs from around the world will regularly stop by for exclusive live performances and I’ll keep you up-to-date with Latin music news and events. \\n\\nTune in every Monday evening and we’ll travel together, making new discoveries and having a blast along the way.",
#    'tags': 'Latin,World',
#    'is_active': True},
#   {'id': 3,
#    'uri': 'https://api.kexp.org/v2/programs/3/',
#    'name': 'Expansions',
#    'description': 'Expansions began in late 1995 as the brainchild of Riz Rollins as a response to the burgeoning acid jazz scene that was enjoying popularity in local clubs, but underexposed on the local airwaves. Even at its inception it has always been important that the show not be commanded by any monolithic style or single host, but has always enjoyed 3 hosts who bring a variety of influences and style to the final mix. An Expansions mix will include old and new releases in its mix in a variety of genres. An Expansions mix can included trip-hop, chill, ambient, drum and bass, house, dub, electronica, jazz, sometimes world music, sometimes rock, sometimes....well sometimes even the most disparate elements come together thanks to the expert curator efforts of its current hosts Kid Hops, Masa, and Riz. \\n\\n-DJ Riz',
#    'tags': 'Electronic',
#    'is_active': True},
#   {'id': 22,
#    'uri': 'https://api.kexp.org/v2/programs/22/',
#    'name': 'Friday Night',
#    'description': 'Electronic, Soul, R&B, Hip-Hop, Rock',
#    'tags': 'Rock,Eclectic,Variety Mix',
#    'is_active': True},
#   {'id': 4,
#    'uri': 'https://api.kexp.org/v2/programs/4/',
#    'name': 'Jazz Theatre',
#    'description': 'I have a personal mission statement in mind for Jazz Theater. That is, to really celebrate the fact that Jazz Is Alive and Thriving. Now! \\n\\nIn recent years, jazz has been cast in an unfortunate historical context -- as something that already happened, and is now over. Or, individual "experts" are too willing to narrowly define jazz - like; it sounds like this, and like that, and like this -- and if it doesn\'t, it isn\'t jazz. \\n\\nI think instead, that jazz, like any vibrant art form, has a mandate to expand and recreate itself -- to try new things, to get better, or at least to be different today than it was yesterday. Certainly jazz has a rich history. But part of that history is expansion and progression. Jazz never has stood still for long, there\'s no reason to think is should now. \\n\\nIn programming Jazz Theater I look for compelling work by artists who have been willing to blaze new trails. Clearly they have all studied the history of jazz, and thankfully they are not willing to be confined by it. Some of Jazz Theater will be familiar and, hopefully, some of it will be like nothing you\'ve ever heard before. \\n\\n-John Gilbreath',
#    'tags': 'Jazz',
#    'is_active': True},
#   {'id': 36,
#    'uri': 'https://api.kexp.org/v2/programs/36/',
#    'name': 'Live on KEXP',
#    'description': '',
#    'tags': 'Live,Eclectic,Variety Mix',
#    'is_active': True},
#   {'id': 34,
#    'uri': 'https://api.kexp.org/v2/programs/34/',
#    'name': 'Mechanical Breakdown',
#    'description': '',
#    'tags': 'Wave,Synth,Post Punk,EBM',
#    'is_active': True},
#   {'id': 5,
#    'uri': 'https://api.kexp.org/v2/programs/5/',
#    'name': 'Midnight in a Perfect World',
#    'description': 'Multi-genre program featuring eclectic sets by a rotating cast of international and local DJs, each building upon a party vibe to kick off your weekend.',
#    'tags': 'Eclectic,DJ,Variety Mix',
#    'is_active': True},
#   {'id': 6,
#    'uri': 'https://api.kexp.org/v2/programs/6/',
#    'name': 'Mind Over Matters',
#    'description': "Mind Over Matters carries a wide range of provocative speakers and guests who bring our listeners viewpoints not often heard in the corporate media. MOM focuses on today's most important social, political and economic issues giving voice to the people directly impacted and involved. By giving a forum to those not normally heard in corporate media, MOM offers a unique perspective on the issues that impact our daily lives. \\n\\nMOM carries a stellar list of nationally produced shows including Alternative Radio, Counterspin, Radio Nation, Making Contact and TUC Radio. We also carry several locally produced shows including The Sustainability Segment, Community Forum and Deep Water. \\n\\nSome of the unique voices you'll hear on MOM include Howard Zinn, Vandana Shiva, Noam Chomsky, David Korten, Molly Ivins, Greg Palast, Winona LaDuke, Robert McChesney, Ralph Nader, Arundhati Roy, Michael Moore, Naomi Klein and John Judge.",
#    'tags': 'Public Affairs',
#    'is_active': False},
#   {'id': 30,
#    'uri': 'https://api.kexp.org/v2/programs/30/',
#    'name': "Mo'Glo",
#    'description': 'Went off the air in 2011.',
#    'tags': 'World',
#    'is_active': False},
#   {'id': 35,
#    'uri': 'https://api.kexp.org/v2/programs/35/',
#    'name': 'Overnight Afrobeats',
#    'description': '',
#    'tags': 'Afrobeat',
#    'is_active': False},
#   {'id': 24,
#    'uri': 'https://api.kexp.org/v2/programs/24/',
#    'name': 'Pacific Notions',
#    'description': 'KEXP',
#    'tags': 'KEXP',
#    'is_active': True},
#   {'id': 7,
#    'uri': 'https://api.kexp.org/v2/programs/7/',
#    'name': 'Positive Vibrations',
#    'description': 'Placing equal legitimacy upon all styles of Jamaican musical expression, Positive Vibrations joins the dots between Ska, Rocksteady, Roots Reggae, Dub, and Dancehall. Kid Hops educates as he entertains - riding rhythms across artists, labels, and decades, he demystifies the connections between producers and studios. From the roughest riddims, to the sweetest harmonies and rudest of rudebwoy deejays, Positive Vibrations provides the perfect blend of Jamaican sounds.',
#    'tags': 'Reggae,World',
#    'is_active': True},
#   {'id': 8,
#    'uri': 'https://api.kexp.org/v2/programs/8/',
#    'name': "Preachin' the Blues",
#    'description': "From out of the swamp and through the woods comes the Preachin' the Blues show. Every Sunday I explore the downhome, uptown and gospel sounds of rhythm and blues music, and the focus is always on the most soulful, gritty, heartfelt and creative artists and material. \\n\\nCountry blues gets a special spotlight in the early morning, but quite often we move into the church for some old time singing, powerful preaching and funky accompaniment. \\n\\nI am a fan of southern soul and I always include something from my collection of Stax and Hi stuff in the mix, but the deep blues are firmly represented in each show with heaping helpings of the three Kings of the blues guitar, the rich character of Chicago's legends, and always a certain amount of Louisiana's magickal mystique. \\n\\n-Johnny Horn",
#    'tags': 'Blues,Country,Roots',
#    'is_active': False}]}

# %%
# Create a session
Session = sessionmaker(bind=engine)
session = Session()
    
# Insert data into the table
try:
    for data in programs_json['results']:
        program = Programs(**data)
        session.add(program)

    # Commit the transaction
    session.commit()
    print("Data inserted successfully!")

except Exception as e:
    # Roll back the transaction if an error occurs
    session.rollback()
    print(f"Error: {e}")

finally:
    # Close the session
    session.close()
# Out:
# Error: (pymysql.err.IntegrityError) (1062, "Duplicate entry '26' for key 'programs.PRIMARY'")
# [SQL: INSERT INTO programs (id, uri, name, description, tags, is_active) VALUES (%(id)s, %(uri)s, %(name)s, %(description)s, %(tags)s, %(is_active)s)]
# [parameters: [{'id': 26, 'uri': 'https://api.kexp.org/v2/programs/26/', 'name': '90.TEEN', 'description': 'Rock,Eclectic,Variety Mix', 'tags': 'Rock,Eclectic,Variety Mix', 'is_active': 1}, {'id': 38, 'uri': 'https://api.kexp.org/v2/programs/38/', 'name': 'Astral Plane', 'description': '', 'tags': 'Rock,Eclectic,Psychedelic', 'is_active': 1}, {'id': 1, 'uri': 'https://api.kexp.org/v2/programs/1/', 'name': 'Audioasis', 'description': "Audioasis is KEXP's long-running Northwest music show hosted by Sharlese Metcalf. Past hosts have included Jonathen Poneman, Jason Hughes, Scott Vand ... (239 characters truncated) ... os, the vinyl, and the future of music. Every first Saturday of the month you can catch Audioasis out in the city LIVE! Tune in Saturday from 6-9 PM.", 'tags': 'Rock,Eclectic,Pacific Northwest', 'is_active': 1}, {'id': 27, 'uri': 'https://api.kexp.org/v2/programs/27/', 'name': 'Best Ambiance', 'description': 'Went off the air in 2011.', 'tags': 'African,World', 'is_active': 0}, {'id': 33, 'uri': 'https://api.kexp.org/v2/programs/33/', 'name': 'Drive Time', 'description': '', 'tags': 'Rock,Eclectic,Variety Mix', 'is_active': 1}, {'id': 32, 'uri': 'https://api.kexp.org/v2/programs/32/', 'name': 'Early', 'description': '', 'tags': 'Rock,Eclectic,Variety Mix', 'is_active': 1}, {'id': 37, 'uri': 'https://api.kexp.org/v2/programs/37/', 'name': 'Eastern Echoes', 'description': '', 'tags': 'Eclectic,Variety,World', 'is_active': 1}, {'id': 2, 'uri': 'https://api.kexp.org/v2/programs/2/', 'name': 'El Sonido', 'description': "El Sonido is a three hour trip around the diverse world of Latin music and culture from South, Central and North America, as well as Spain and the re ... (596 characters truncated) ... h Latin music news and events. \\n\\nTune in every Monday evening and we’ll travel together, making new discoveries and having a blast along the way.", 'tags': 'Latin,World', 'is_active': 1}  ... displaying 10 of 20 total bound parameter sets ...  {'id': 7, 'uri': 'https://api.kexp.org/v2/programs/7/', 'name': 'Positive Vibrations', 'description': 'Placing equal legitimacy upon all styles of Jamaican musical expression, Positive Vibrations joins the dots between Ska, Rocksteady, Roots Reggae, Du ... (171 characters truncated) ... om the roughest riddims, to the sweetest harmonies and rudest of rudebwoy deejays, Positive Vibrations provides the perfect blend of Jamaican sounds.', 'tags': 'Reggae,World', 'is_active': 1}, {'id': 8, 'uri': 'https://api.kexp.org/v2/programs/8/', 'name': "Preachin' the Blues", 'description': "From out of the swamp and through the woods comes the Preachin' the Blues show. Every Sunday I explore the downhome, uptown and gospel sounds of rhyt ... (502 characters truncated) ...  Kings of the blues guitar, the rich character of Chicago's legends, and always a certain amount of Louisiana's magickal mystique. \\n\\n-Johnny Horn", 'tags': 'Blues,Country,Roots', 'is_active': 0}]]
# (Background on this error at: https://sqlalche.me/e/20/gkpj)

# %%
# Create a session
Session = sessionmaker(bind=engine)
session = Session()
# Query the table for 5 random rows
try:
    random_rows = session.query(Programs).order_by(func.rand()).limit(5).all()
    for row in random_rows:
        print(row.id, row.uri, row.name, row.description, row.tags, row.is_active)

except Exception as e:
    print(f"Error: {e}")

finally:
    # Close the session
    session.close()
# Out:
# 38 https://api.kexp.org/v2/programs/38/ Astral Plane  Rock,Eclectic,Psychedelic True
# 8 https://api.kexp.org/v2/programs/8/ Preachin' the Blues From out of the swamp and through the woods comes the Preachin' the Blues show. Every Sunday I explore the downhome, uptown and gospel sounds of rhythm and blues music, and the focus is always on the most soulful, gritty, heartfelt and creative artists and material. \n\nCountry blues gets a special spotlight in the early morning, but quite often we move into the church for some old time singing, powerful preaching and funky accompaniment. \n\nI am a fan of southern soul and I always include something from my collection of Stax and Hi stuff in the mix, but the deep blues are firmly represented in each show with heaping helpings of the three Kings of the blues guitar, the rich character of Chicago's legends, and always a certain amount of Louisiana's magickal mystique. \n\n-Johnny Horn Blues,Country,Roots False
# 22 https://api.kexp.org/v2/programs/22/ Friday Night Electronic, Soul, R&B, Hip-Hop, Rock Rock,Eclectic,Variety Mix True
# 5 https://api.kexp.org/v2/programs/5/ Midnight in a Perfect World Multi-genre program featuring eclectic sets by a rotating cast of international and local DJs, each building upon a party vibe to kick off your weekend. Eclectic,DJ,Variety Mix True
# 37 https://api.kexp.org/v2/programs/37/ Eastern Echoes  Eclectic,Variety,World True

# %%
while programs_json['next'] != None:
    programs = requests.get(programs_json['next'])
    programs_json=programs.json()
    # Create a session
    Session = sessionmaker(bind=engine)
    session = Session()
        
    # Insert data into the table
    try:
        for data in programs_json['results']:
            user = Programs(**data)
            session.add(user)

        # Commit the transaction
        session.commit()
        print("Data inserted successfully!")

    except Exception as e:
        # Roll back the transaction if an error occurs
        session.rollback()
        print(f"Error: {e}")

    finally:
        # Close the session
        session.close()
# Out:
# Data inserted successfully!

# %% [markdown]
# ### Shows Populate

# %%
shows = requests.get(urls['shows'])
shows_json=shows.json()
print(f"Total Entries: {shows_json['count']}")
# Out:
# Total Entries: 59731

# %%
shows_json['results'][0]
# Out:
# {'id': 59753,
#  'uri': 'https://api.kexp.org/v2/shows/59753/',
#  'program': 18,
#  'program_uri': 'https://api.kexp.org/v2/programs/18/',
#  'hosts': [43],
#  'host_uris': ['https://api.kexp.org/v2/hosts/43/'],
#  'program_name': 'Variety Mix',
#  'program_tags': 'Rock,Eclectic,Variety Mix',
#  'host_names': ['Troy Nelson'],
#  'tagline': '',
#  'image_uri': 'https://www.kexp.org/filer/canonical/1583367959/22030/',
#  'start_time': '2024-03-23T15:01:26-07:00'}

# %%
# Create a session
Session = sessionmaker(bind=engine)
session = Session()
    
# Insert data into the table
try:
    for data in shows_json['results']:
        # Keys to drop
        keys_to_drop = ['host_uris', 'host_names']
        # New dictionary without the specified keys
        data = {key: value for key, value in data.items() if key not in keys_to_drop}
        show = Shows(**data)
        session.add(show)

    # Commit the transaction
    session.commit()
    print("Data inserted successfully!")

except Exception as e:
    # Roll back the transaction if an error occurs
    session.rollback()
    print(f"Error: {e}")

finally:
    # Close the session
    session.close()
# Out:
# Data inserted successfully!

# %%
for _ in range(5):
    shows = requests.get(shows_json['next'])
    shows_json=shows.json()
    # Create a session
    Session = sessionmaker(bind=engine)
    session = Session()
        
    # Insert data into the table
    try:
        for data in shows_json['results']:
            # Keys to drop
            keys_to_drop = ['host_uris', 'host_names']
            # New dictionary without the specified keys
            data = {key: value for key, value in data.items() if key not in keys_to_drop}
            show = Shows(**data)
            session.add(show)

        # Commit the transaction
        session.commit()
        print("Data inserted successfully!")

    except Exception as e:
        # Roll back the transaction if an error occurs
        session.rollback()
        print(f"Error: {e}")

    finally:
        # Close the session
        session.close()
# Out:
# Data inserted successfully!
# Data inserted successfully!
# Data inserted successfully!
# Data inserted successfully!
# Data inserted successfully!

# %% [markdown]
# ### Plays Populate

# %%
shows = requests.get(urls['plays'])
plays_json=shows.json()

# %%
plays_json['results'][0]
# Out:
# {'id': 3326526,
#  'uri': 'https://api.kexp.org/v2/plays/3326526/',
#  'airdate': '2024-03-25T07:38:30-07:00',
#  'show': 59770,
#  'show_uri': 'https://api.kexp.org/v2/shows/59770/',
#  'image_uri': 'https://ia804704.us.archive.org/9/items/mbid-0c5fc37e-c75c-49ee-9609-e69e7c0743ee/mbid-0c5fc37e-c75c-49ee-9609-e69e7c0743ee-2200354304_thumb500.jpg',
#  'thumbnail_uri': 'https://ia904704.us.archive.org/9/items/mbid-0c5fc37e-c75c-49ee-9609-e69e7c0743ee/mbid-0c5fc37e-c75c-49ee-9609-e69e7c0743ee-2200354304_thumb250.jpg',
#  'song': 'Deep Red Bells',
#  'track_id': '3087c18d-c59f-37e4-87bc-17b6683c509c',
#  'recording_id': '74a939b9-995b-4bc6-8393-1c52aae295d9',
#  'artist': 'Neko Case',
#  'artist_ids': ['e13d2935-8c42-4c0a-96d7-654062acf106'],
#  'album': 'Blacklisted',
#  'release_id': '0c5fc37e-c75c-49ee-9609-e69e7c0743ee',
#  'release_group_id': 'ec08962a-433c-3071-9978-488e44a25a3b',
#  'labels': ['Bloodshot Records'],
#  'label_ids': ['c1a4129a-95dd-4e8c-b42e-7cd9fc3c208b'],
#  'release_date': '2002-08-20',
#  'rotation_status': None,
#  'is_local': True,
#  'is_request': False,
#  'is_live': False,
#  'comment': 'Good morning, John, Owen and Co! Saw Neko Case last night at the Edmonds Center for the Arts. She was amazing. Powerful voice that filled the small venue. So cool to see her in Edmonds. Anyway, if it fits the set or tomorrow, I would love to hear a Neko song. Thanks so much. Have a great week!\nTodd in Edmonds',
#  'play_type': 'trackplay'}

# %%
# Create a session
Session = sessionmaker(bind=engine)
session = Session()
    
# Insert data into the table
try:
    for data in plays_json['results']:
        if 'song' in data.keys():
            # Rename Keys
            data['show_id'] = data['show']
            # Keys to drop
            keys_to_drop = ['show', 'show_uri', 'labels', 'label_ids', 'rotation_status', 'play_type','image_uri', 'thumbnail_uri', 'artist_ids']

            # New dictionary without the specified keys
            data = {key: value for key, value in data.items() if key not in keys_to_drop}
            play = Plays(**data)
            session.add(play)

    # Commit the transaction
    session.commit()
    print("Data inserted successfully!")

except Exception as e:
    # Roll back the transaction if an error occurs
    session.rollback()
    print(f"Error: {e}")

finally:
    # Close the session
    session.close()
# Out:
# Error: (pymysql.err.IntegrityError) (1048, "Column 'track_id' cannot be null")
# [SQL: INSERT INTO plays (id, uri, airdate, show_id, song, track_id, recording_id, artist, album, release_id, release_group_id, release_date, is_local, is_request, is_live, comment) VALUES (%(id)s, %(uri)s, %(airdate)s, %(show_id)s, %(song)s, %(track_id)s, %(recording_id)s, %(artist)s, %(album)s, %(release_id)s, %(release_group_id)s, %(release_date)s, %(is_local)s, %(is_request)s, %(is_live)s, %(comment)s)]
# [parameters: [{'id': 3326526, 'uri': 'https://api.kexp.org/v2/plays/3326526/', 'airdate': '2024-03-25T07:38:30-07:00', 'show_id': 59770, 'song': 'Deep Red Bells', 'track_id': '3087c18d-c59f-37e4-87bc-17b6683c509c', 'recording_id': '74a939b9-995b-4bc6-8393-1c52aae295d9', 'artist': 'Neko Case', 'album': 'Blacklisted', 'release_id': '0c5fc37e-c75c-49ee-9609-e69e7c0743ee', 'release_group_id': 'ec08962a-433c-3071-9978-488e44a25a3b', 'release_date': '2002-08-20', 'is_local': 1, 'is_request': 0, 'is_live': 0, 'comment': 'Good morning, John, Owen and Co! Saw Neko Case last night at the Edmonds Center for the Arts. She was amazing. Powerful voice that filled the small v ... (13 characters truncated) ...  to see her in Edmonds. Anyway, if it fits the set or tomorrow, I would love to hear a Neko song. Thanks so much. Have a great week!\nTodd in Edmonds'}, {'id': 3326524, 'uri': 'https://api.kexp.org/v2/plays/3326524/', 'airdate': '2024-03-25T07:35:23-07:00', 'show_id': 59770, 'song': 'Gone', 'track_id': '7e7df2b2-6b27-4515-b9bf-b7e6f6de2fc5', 'recording_id': 'f0422cb6-cb76-438f-9d3c-24dfe025cf9c', 'artist': 'Pillow Queens', 'album': 'Name Your Sorrow', 'release_id': '9ea727c8-2b2c-441a-9455-e0ee7476a43a', 'release_group_id': '691b26c1-deac-4486-9f3b-5c0f34c685d5', 'release_date': '2024-04-19', 'is_local': 0, 'is_request': 0, 'is_live': 0, 'comment': 'Irish band Pillow Queens new album Name Your Sorrow will be out April 19, 2024!\nhttps://www.pillowqueens.com/'}, {'id': 3326523, 'uri': 'https://api.kexp.org/v2/plays/3326523/', 'airdate': '2024-03-25T07:31:56-07:00', 'show_id': 59770, 'song': 'Earth Sign', 'track_id': 'fd8192ff-249a-4a27-9163-f848c7433f22', 'recording_id': 'c2f69043-a0f3-4c9f-8732-8aff52afe3de', 'artist': 'Brittany Howard', 'album': 'What Now', 'release_id': 'a00930c7-afe5-4ec2-a11c-0b2fc14c895c', 'release_group_id': '164fc46f-f349-4708-a676-c93f686b761a', 'release_date': '2024-02-09', 'is_local': 0, 'is_request': 0, 'is_live': 0, 'comment': None}, {'id': 3326522, 'uri': 'https://api.kexp.org/v2/plays/3326522/', 'airdate': '2024-03-25T07:28:44-07:00', 'show_id': 59770, 'song': 'Georgia on My Mind', 'track_id': None, 'recording_id': 'f0d04f76-b77a-4e88-8cdd-37aeba83e6cb', 'artist': 'Ray Charles', 'album': 'Georgia on My Mind', 'release_id': None, 'release_group_id': '1477a3a0-ebb3-434c-8b29-5e986b85778b', 'release_date': '1960-01-01', 'is_local': 0, 'is_request': 0, 'is_live': 0, 'comment': 'This was written by great American songwriter Hoagy Carmichael and Stuart Gorrell in 1930. Ray Charles recorded this song on this day in 1958. On Apr ... (489 characters truncated) ... t learned to play the piano. He then moved to Seattle, where he began to be published as a musician.: https://www.biography.com/musician/ray-charles.'}, {'id': 3326519, 'uri': 'https://api.kexp.org/v2/plays/3326519/', 'airdate': '2024-03-25T07:19:34-07:00', 'show_id': 59770, 'song': 'Heroes', 'track_id': 'b5610495-8f75-44a6-b238-787bd41472c8', 'recording_id': 'aa0108bb-fee5-4337-b249-835da501ccc9', 'artist': 'Depeche Mode', 'album': 'LiVE SPiRiTS SOUNDTRACK', 'release_id': '5d6f4761-135d-4df8-82db-331d2e5d9976', 'release_group_id': 'a2039615-6931-4ba7-a1be-bedbbb71233d', 'release_date': '2020-06-26', 'is_local': 0, 'is_request': 0, 'is_live': 0, 'comment': "Depeche Mode cover of David Bowie's Heroes.\n\nHeroes holds significance in the early history and formation of the band. Before adopting the name Dep ... (143 characters truncated) ... sal that they heard singer Dave Gahan performing 'Heroes', leaving them impressed with his rendition and leading to his invitation to join the group."}, {'id': 3326518, 'uri': 'https://api.kexp.org/v2/plays/3326518/', 'airdate': '2024-03-25T07:14:19-07:00', 'show_id': 59770, 'song': 'Tennessee Rise', 'track_id': '56d23b52-c37d-4c26-a51b-2f4a691d2971', 'recording_id': '8d8b091a-b356-410a-86a7-373c7f9c23da', 'artist': 'The Tennessee Freedom Singers', 'album': 'Tennessee Rise', 'release_id': 'd7aea435-59c0-4217-b9d5-c20919b ...
# (Background on this error at: https://sqlalche.me/e/20/gkpj)

# %%
for data in plays_json['results']:
    if 'song' in data.keys() and :
        print(data)
# Out:
# {'id': 3326525, 'uri': 'https://api.kexp.org/v2/plays/3326525/', 'airdate': '2024-03-25T07:38:11-07:00', 'show': 59770, 'show_uri': 'https://api.kexp.org/v2/shows/59770/', 'image_uri': '', 'thumbnail_uri': '', 'comment': '', 'play_type': 'airbreak', 'show_id': 59770}
# {'id': 3326520, 'uri': 'https://api.kexp.org/v2/plays/3326520/', 'airdate': '2024-03-25T07:25:33-07:00', 'show': 59770, 'show_uri': 'https://api.kexp.org/v2/shows/59770/', 'image_uri': '', 'thumbnail_uri': '', 'comment': '', 'play_type': 'airbreak', 'show_id': 59770}
# {'id': 3326515, 'uri': 'https://api.kexp.org/v2/plays/3326515/', 'airdate': '2024-03-25T07:01:20-07:00', 'show': 59770, 'show_uri': 'https://api.kexp.org/v2/shows/59770/', 'image_uri': '', 'thumbnail_uri': '', 'comment': '', 'play_type': 'airbreak', 'show_id': 59770}
# {'id': 3326512, 'uri': 'https://api.kexp.org/v2/plays/3326512/', 'airdate': '2024-03-25T06:51:13-07:00', 'show': 59769, 'show_uri': 'https://api.kexp.org/v2/shows/59769/', 'image_uri': '', 'thumbnail_uri': '', 'comment': '', 'play_type': 'airbreak', 'show_id': 59769}
# {'id': 3326505, 'uri': 'https://api.kexp.org/v2/plays/3326505/', 'airdate': '2024-03-25T06:32:42-07:00', 'show': 59769, 'show_uri': 'https://api.kexp.org/v2/shows/59769/', 'image_uri': '', 'thumbnail_uri': '', 'comment': '', 'play_type': 'airbreak', 'show_id': 59769}

# %%
plays_json['results']
# Out:
# [{'id': 3326526,
#   'uri': 'https://api.kexp.org/v2/plays/3326526/',
#   'airdate': '2024-03-25T07:38:30-07:00',
#   'show': 59770,
#   'show_uri': 'https://api.kexp.org/v2/shows/59770/',
#   'image_uri': 'https://ia804704.us.archive.org/9/items/mbid-0c5fc37e-c75c-49ee-9609-e69e7c0743ee/mbid-0c5fc37e-c75c-49ee-9609-e69e7c0743ee-2200354304_thumb500.jpg',
#   'thumbnail_uri': 'https://ia904704.us.archive.org/9/items/mbid-0c5fc37e-c75c-49ee-9609-e69e7c0743ee/mbid-0c5fc37e-c75c-49ee-9609-e69e7c0743ee-2200354304_thumb250.jpg',
#   'song': 'Deep Red Bells',
#   'track_id': '3087c18d-c59f-37e4-87bc-17b6683c509c',
#   'recording_id': '74a939b9-995b-4bc6-8393-1c52aae295d9',
#   'artist': 'Neko Case',
#   'artist_ids': ['e13d2935-8c42-4c0a-96d7-654062acf106'],
#   'album': 'Blacklisted',
#   'release_id': '0c5fc37e-c75c-49ee-9609-e69e7c0743ee',
#   'release_group_id': 'ec08962a-433c-3071-9978-488e44a25a3b',
#   'labels': ['Bloodshot Records'],
#   'label_ids': ['c1a4129a-95dd-4e8c-b42e-7cd9fc3c208b'],
#   'release_date': '2002-08-20',
#   'rotation_status': None,
#   'is_local': True,
#   'is_request': False,
#   'is_live': False,
#   'comment': 'Good morning, John, Owen and Co! Saw Neko Case last night at the Edmonds Center for the Arts. She was amazing. Powerful voice that filled the small venue. So cool to see her in Edmonds. Anyway, if it fits the set or tomorrow, I would love to hear a Neko song. Thanks so much. Have a great week!\nTodd in Edmonds',
#   'play_type': 'trackplay',
#   'show_id': 59770},
#  {'id': 3326525,
#   'uri': 'https://api.kexp.org/v2/plays/3326525/',
#   'airdate': '2024-03-25T07:38:11-07:00',
#   'show': 59770,
#   'show_uri': 'https://api.kexp.org/v2/shows/59770/',
#   'image_uri': '',
#   'thumbnail_uri': '',
#   'comment': '',
#   'play_type': 'airbreak',
#   'show_id': 59770},
#  {'id': 3326524,
#   'uri': 'https://api.kexp.org/v2/plays/3326524/',
#   'airdate': '2024-03-25T07:35:23-07:00',
#   'show': 59770,
#   'show_uri': 'https://api.kexp.org/v2/shows/59770/',
#   'image_uri': 'https://ia601301.us.archive.org/19/items/mbid-9ea727c8-2b2c-441a-9455-e0ee7476a43a/mbid-9ea727c8-2b2c-441a-9455-e0ee7476a43a-37859198775_thumb500.jpg',
#   'thumbnail_uri': 'https://ia601301.us.archive.org/19/items/mbid-9ea727c8-2b2c-441a-9455-e0ee7476a43a/mbid-9ea727c8-2b2c-441a-9455-e0ee7476a43a-37859198775_thumb250.jpg',
#   'song': 'Gone',
#   'track_id': '7e7df2b2-6b27-4515-b9bf-b7e6f6de2fc5',
#   'recording_id': 'f0422cb6-cb76-438f-9d3c-24dfe025cf9c',
#   'artist': 'Pillow Queens',
#   'artist_ids': ['3329e0ce-14b6-4b51-b658-85f6392554a3'],
#   'album': 'Name Your Sorrow',
#   'release_id': '9ea727c8-2b2c-441a-9455-e0ee7476a43a',
#   'release_group_id': '691b26c1-deac-4486-9f3b-5c0f34c685d5',
#   'labels': ['Royal Mountain Records'],
#   'label_ids': ['564dc8fb-cbd0-453b-ad29-dd867556d041'],
#   'release_date': '2024-04-19',
#   'rotation_status': 'Medium',
#   'is_local': False,
#   'is_request': False,
#   'is_live': False,
#   'comment': 'Irish band Pillow Queens new album Name Your Sorrow will be out April 19, 2024!\nhttps://www.pillowqueens.com/',
#   'play_type': 'trackplay',
#   'show_id': 59770},
#  {'id': 3326523,
#   'uri': 'https://api.kexp.org/v2/plays/3326523/',
#   'airdate': '2024-03-25T07:31:56-07:00',
#   'show': 59770,
#   'show_uri': 'https://api.kexp.org/v2/shows/59770/',
#   'image_uri': 'https://ia601202.us.archive.org/29/items/mbid-a00930c7-afe5-4ec2-a11c-0b2fc14c895c/mbid-a00930c7-afe5-4ec2-a11c-0b2fc14c895c-37270007131_thumb500.jpg',
#   'thumbnail_uri': 'https://ia601202.us.archive.org/29/items/mbid-a00930c7-afe5-4ec2-a11c-0b2fc14c895c/mbid-a00930c7-afe5-4ec2-a11c-0b2fc14c895c-37270007131_thumb250.jpg',
#   'song': 'Earth Sign',
#   'track_id': 'fd8192ff-249a-4a27-9163-f848c7433f22',
#   'recording_id': 'c2f69043-a0f3-4c9f-8732-8aff52afe3de',
#   'artist': 'Brittany Howard',
#   'artist_ids': ['03eda2c4-a2b3-4a4e-9527-6791b0ed9d2d'],
#   'album': 'What Now',
#   'release_id': 'a00930c7-afe5-4ec2-a11c-0b2fc14c895c',
#   'release_group_id': '164fc46f-f349-4708-a676-c93f686b761a',
#   'labels': ['Island'],
#   'label_ids': ['dfd92cd3-4888-46d2-b968-328b1feb2642'],
#   'release_date': '2024-02-09',
#   'rotation_status': 'Heavy',
#   'is_local': False,
#   'is_request': False,
#   'is_live': False,
#   'comment': None,
#   'play_type': 'trackplay',
#   'show_id': 59770},
#  {'id': 3326522,
#   'uri': 'https://api.kexp.org/v2/plays/3326522/',
#   'airdate': '2024-03-25T07:28:44-07:00',
#   'show': 59770,
#   'show_uri': 'https://api.kexp.org/v2/shows/59770/',
#   'image_uri': 'https://coverartarchive.org/release/1a8f15cf-07bb-42da-a422-0d53d98fbef8/33376725258-500.jpg',
#   'thumbnail_uri': 'https://coverartarchive.org/release/1a8f15cf-07bb-42da-a422-0d53d98fbef8/33376725258-250.jpg',
#   'song': 'Georgia on My Mind',
#   'track_id': None,
#   'recording_id': 'f0d04f76-b77a-4e88-8cdd-37aeba83e6cb',
#   'artist': 'Ray Charles',
#   'artist_ids': ['2ce02909-598b-44ef-a456-151ba0a3bd70'],
#   'album': 'Georgia on My Mind',
#   'release_id': None,
#   'release_group_id': '1477a3a0-ebb3-434c-8b29-5e986b85778b',
#   'labels': ['ABC-Paramount'],
#   'label_ids': ['ef36d3a8-fcc9-4e50-bb80-27bcfd0bbdad'],
#   'release_date': '1960-01-01',
#   'rotation_status': None,
#   'is_local': False,
#   'is_request': False,
#   'is_live': False,
#   'comment': 'This was written by great American songwriter Hoagy Carmichael and Stuart Gorrell in 1930. Ray Charles recorded this song on this day in 1958. On April 24, 1979, this became the official state song of Georgia, replacing a song titled "Georgia." Ray Charles performed the song the ceremony that day: https://bit.ly/3oUkXxE. Willie Nelson sang this at Charles\' funeral in 2004.\n\nRay Charles was born in Albany, Georgia and moved to Florida as a child. At the age of 5, he began losing his sight gradually;  by the age of 7, he was completely blind. In Florida, he studied at the St. Augustine school for the deaf and blind, where he first learned to play the piano. He then moved to Seattle, where he began to be published as a musician.: https://www.biography.com/musician/ray-charles.',
#   'play_type': 'trackplay',
#   'show_id': 59770},
#  {'id': 3326520,
#   'uri': 'https://api.kexp.org/v2/plays/3326520/',
#   'airdate': '2024-03-25T07:25:33-07:00',
#   'show': 59770,
#   'show_uri': 'https://api.kexp.org/v2/shows/59770/',
#   'image_uri': '',
#   'thumbnail_uri': '',
#   'comment': '',
#   'play_type': 'airbreak',
#   'show_id': 59770},
#  {'id': 3326519,
#   'uri': 'https://api.kexp.org/v2/plays/3326519/',
#   'airdate': '2024-03-25T07:19:34-07:00',
#   'show': 59770,
#   'show_uri': 'https://api.kexp.org/v2/shows/59770/',
#   'image_uri': 'https://ia801703.us.archive.org/30/items/mbid-8c5c2827-02f2-4654-9216-96cb7655996c/mbid-8c5c2827-02f2-4654-9216-96cb7655996c-36552336267_thumb500.jpg',
#   'thumbnail_uri': 'https://ia801703.us.archive.org/30/items/mbid-8c5c2827-02f2-4654-9216-96cb7655996c/mbid-8c5c2827-02f2-4654-9216-96cb7655996c-36552336267_thumb250.jpg',
#   'song': 'Heroes',
#   'track_id': 'b5610495-8f75-44a6-b238-787bd41472c8',
#   'recording_id': 'aa0108bb-fee5-4337-b249-835da501ccc9',
#   'artist': 'Depeche Mode',
#   'artist_ids': ['8538e728-ca0b-4321-b7e5-cff6565dd4c0'],
#   'album': 'LiVE SPiRiTS SOUNDTRACK',
#   'release_id': '5d6f4761-135d-4df8-82db-331d2e5d9976',
#   'release_group_id': 'a2039615-6931-4ba7-a1be-bedbbb71233d',
#   'labels': ['Sony Music'],
#   'label_ids': ['9e6b4d7f-4958-4db7-8504-d89e315836af'],
#   'release_date': '2020-06-26',
#   'rotation_status': 'Library',
#   'is_local': False,
#   'is_request': False,
#   'is_live': False,
#   'comment': "Depeche Mode cover of David Bowie's Heroes.\n\nHeroes holds significance in the early history and formation of the band. Before adopting the name Depeche Mode, the ensemble was known as Composition Of Sound, consisting of Vince Clarke, Andrew Fletcher, and Martin Gore. It was during a rehearsal that they heard singer Dave Gahan performing 'Heroes', leaving them impressed with his rendition and leading to his invitation to join the group.",
#   'play_type': 'trackplay',
#   'show_id': 59770},
#  {'id': 3326518,
#   'uri': 'https://api.kexp.org/v2/plays/3326518/',
#   'airdate': '2024-03-25T07:14:19-07:00',
#   'show': 59770,
#   'show_uri': 'https://api.kexp.org/v2/shows/59770/',
#   'image_uri': 'https://ia800202.us.archive.org/16/items/mbid-d7aea435-59c0-4217-b9d5-c20919ba704a/mbid-d7aea435-59c0-4217-b9d5-c20919ba704a-38327429795_thumb500.jpg',
#   'thumbnail_uri': 'https://ia800202.us.archive.org/16/items/mbid-d7aea435-59c0-4217-b9d5-c20919ba704a/mbid-d7aea435-59c0-4217-b9d5-c20919ba704a-38327429795_thumb250.jpg',
#   'song': 'Tennessee Rise',
#   'track_id': '56d23b52-c37d-4c26-a51b-2f4a691d2971',
#   'recording_id': '8d8b091a-b356-410a-86a7-373c7f9c23da',
#   'artist': 'The Tennessee Freedom Singers',
#   'artist_ids': ['b9d38e96-8e84-4a12-ba83-7b081500df8e'],
#   'album': 'Tennessee Rise',
#   'release_id': 'd7aea435-59c0-4217-b9d5-c20919ba704a',
#   'release_group_id': 'd96835bf-6e27-406a-8180-2c823c6bef2d',
#   'labels': ['Thirty Tigers'],
#   'label_ids': ['5ecd57fa-e156-453e-94c9-3c8f1832b3ec'],
#   'release_date': '2024-03-13',
#   'rotation_status': 'Light',
#   'is_local': False,
#   'is_request': False,
#   'is_live': False,
#   'comment': 'Allison Russell, Brandi Carlile, Brittany Howard, Brittney Spencer, Amanda Shires, Emmylou Harris, Langhorne Slim and more — billed as the Tennessee Freedom Singers — released \'Tennessee Rise\' to get out the vote in Tennessee. In a post on Instagram, Russell wrote the song is “a call to all who care about human rights, voting rights, equality, democracy & freedom in Tennessee“ and added "It has never been more important to use our powerful voices & votes in Tennessee. Go and make yourself known! Register! Vote! Rise!”',
#   'play_type': 'trackplay',
#   'show_id': 59770},
#  {'id': 3326517,
#   'uri': 'https://api.kexp.org/v2/plays/3326517/',
#   'airdate': '2024-03-25T07:10:17-07:00',
#   'show': 59770,
#   'show_uri': 'https://api.kexp.org/v2/shows/59770/',
#   'image_uri': 'https://ia601709.us.archive.org/7/items/mbid-530bbddf-949d-4951-bcca-483f297699f2/mbid-530bbddf-949d-4951-bcca-483f297699f2-27539120499_thumb500.jpg',
#   'thumbnail_uri': 'https://ia601709.us.archive.org/7/items/mbid-530bbddf-949d-4951-bcca-483f297699f2/mbid-530bbddf-949d-4951-bcca-483f297699f2-27539120499_thumb250.jpg',
#   'song': 'Everybody Deserves To Be Free',
#   'track_id': '731d1c8e-3052-4de8-b642-48178f005cb5',
#   'recording_id': '53cde242-2993-4fa1-b45b-3e4ef652595d',
#   'artist': 'Resistance Revival Chorus',
#   'artist_ids': ['4956c0b6-5b55-46e7-9f5f-da7c3cdc5b52'],
#   'album': 'This Joy',
#   'release_id': '78e536ec-281f-413d-83c4-d05b976089b8',
#   'release_group_id': 'bdfe4191-371d-45d6-b58d-3d37a8b2106e',
#   'labels': ['Righteous Babe Records'],
#   'label_ids': ['9d1ac05c-138a-41d4-a869-59364e81759c'],
#   'release_date': '2020-10-16',
#   'rotation_status': 'Library',
#   'is_local': False,
#   'is_request': False,
#   'is_live': False,
#   'comment': "The Resistance Revival Chorus was founded in the wake of the 2017 Women's March and strives to center women in music and address how historically marginalized women have been in the music industry\n\nhttps://youtu.be/Hc8WUh0fCAw",
#   'play_type': 'trackplay',
#   'show_id': 59770},
#  {'id': 3326516,
#   'uri': 'https://api.kexp.org/v2/plays/3326516/',
#   'airdate': '2024-03-25T07:02:14-07:00',
#   'show': 59770,
#   'show_uri': 'https://api.kexp.org/v2/shows/59770/',
#   'image_uri': 'https://ia902502.us.archive.org/34/items/mbid-1dcb3142-8b1f-40a7-9c56-4edee89366cb/mbid-1dcb3142-8b1f-40a7-9c56-4edee89366cb-33140079740_thumb500.jpg',
#   'thumbnail_uri': 'https://ia802502.us.archive.org/34/items/mbid-1dcb3142-8b1f-40a7-9c56-4edee89366cb/mbid-1dcb3142-8b1f-40a7-9c56-4edee89366cb-33140079740_thumb250.jpg',
#   'song': 'Amazing Grace',
#   'track_id': 'f9eb8256-9235-31c2-b0ce-e20f268e952b',
#   'recording_id': '60ea1299-3808-418c-accb-238b8b7db528',
#   'artist': 'Aretha Franklin',
#   'artist_ids': ['2f9ecbed-27be-40e6-abca-6de49d50299e'],
#   'album': 'Amazing Grace',
#   'release_id': '1dcb3142-8b1f-40a7-9c56-4edee89366cb',
#   'release_group_id': '9e9b6cb5-2398-3aa7-b0c3-80c73e30b663',
#   'labels': ['Atlantic'],
#   'label_ids': ['50c384a2-0b44-401b-b893-8181173339c7'],
#   'release_date': '1972-03-25',
#   'rotation_status': None,
#   'is_local': False,
#   'is_request': False,
#   'is_live': False,
#   'comment': 'Happy 82nd to the late, great, greatest, Aretha Franklin. Born on this day in 1942.',
#   'play_type': 'trackplay',
#   'show_id': 59770},
#  {'id': 3326515,
#   'uri': 'https://api.kexp.org/v2/plays/3326515/',
#   'airdate': '2024-03-25T07:01:20-07:00',
#   'show': 59770,
#   'show_uri': 'https://api.kexp.org/v2/shows/59770/',
#   'image_uri': '',
#   'thumbnail_uri': '',
#   'comment': '',
#   'play_type': 'airbreak',
#   'show_id': 59770},
#  {'id': 3326514,
#   'uri': 'https://api.kexp.org/v2/plays/3326514/',
#   'airdate': '2024-03-25T06:56:23-07:00',
#   'show': 59769,
#   'show_uri': 'https://api.kexp.org/v2/shows/59769/',
#   'image_uri': 'https://ia801609.us.archive.org/9/items/mbid-6b663d16-5675-4944-893c-0a79821123bd/mbid-6b663d16-5675-4944-893c-0a79821123bd-10920603755_thumb500.jpg',
#   'thumbnail_uri': 'https://ia801609.us.archive.org/9/items/mbid-6b663d16-5675-4944-893c-0a79821123bd/mbid-6b663d16-5675-4944-893c-0a79821123bd-10920603755_thumb250.jpg',
#   'song': 'Heartbreak to Hate',
#   'track_id': 'fd34f863-63a1-3370-b720-c47050864c00',
#   'recording_id': 'f8247eee-fabc-40c1-a1ce-c7a7b4c37bd6',
#   'artist': 'Angelfish',
#   'artist_ids': ['35a125bb-674e-4155-b6b8-bfde69a3f3e7'],
#   'album': 'Angelfish',
#   'release_id': '6b663d16-5675-4944-893c-0a79821123bd',
#   'release_group_id': 'b355c98b-66b4-359a-b3ea-32969a617fd0',
#   'labels': ['Radioactive Records'],
#   'label_ids': ['91bbf0d3-63b9-4339-83ff-be86ecb514f6'],
#   'release_date': '1994-02-15',
#   'rotation_status': None,
#   'is_local': False,
#   'is_request': False,
#   'is_live': False,
#   'comment': "Angelfish was Shirley Manson's pre-Garbage band.\n\nThank you for listening to Early with Lisa LeClair! Stay tuned for the Morning Show with John Richards!",
#   'play_type': 'trackplay',
#   'show_id': 59769},
#  {'id': 3326513,
#   'uri': 'https://api.kexp.org/v2/plays/3326513/',
#   'airdate': '2024-03-25T06:52:32-07:00',
#   'show': 59769,
#   'show_uri': 'https://api.kexp.org/v2/shows/59769/',
#   'image_uri': 'https://ia601605.us.archive.org/17/items/mbid-867e7159-8052-3091-86a4-0d0c48fd7f66/mbid-867e7159-8052-3091-86a4-0d0c48fd7f66-9471823684_thumb500.jpg',
#   'thumbnail_uri': 'https://ia601605.us.archive.org/17/items/mbid-867e7159-8052-3091-86a4-0d0c48fd7f66/mbid-867e7159-8052-3091-86a4-0d0c48fd7f66-9471823684_thumb250.jpg',
#   'song': 'Looking for You (I Was)',
#   'track_id': '9f8a71a2-28b0-3bcb-aa8d-f37e897d8387',
#   'recording_id': '74971d94-e869-4dcf-a71b-89b7a3c5e175',
#   'artist': 'Patti Smith',
#   'artist_ids': ['d135874d-9cae-4fef-97e3-36acbd9f5a26'],
#   'album': 'Dream of Life',
#   'release_id': '867e7159-8052-3091-86a4-0d0c48fd7f66',
#   'release_group_id': '92f0659b-0d81-3491-a2ad-6028ddcbd628',
#   'labels': ['Arista'],
#   'label_ids': ['c62e3985-6370-446a-bfb8-f1f6122e9c33'],
#   'release_date': '1988-03-25',
#   'rotation_status': None,
#   'is_local': False,
#   'is_request': False,
#   'is_live': False,
#   'comment': 'Fifth studio album from Patti Smith, released in 1988.\n\n"Dream of Life" was also the title of a documentary on Patti Smith.\n\nhttps://www.imdb.com/title/tt0940620/',
#   'play_type': 'trackplay',
#   'show_id': 59769},
#  {'id': 3326512,
#   'uri': 'https://api.kexp.org/v2/plays/3326512/',
#   'airdate': '2024-03-25T06:51:13-07:00',
#   'show': 59769,
#   'show_uri': 'https://api.kexp.org/v2/shows/59769/',
#   'image_uri': '',
#   'thumbnail_uri': '',
#   'comment': '',
#   'play_type': 'airbreak',
#   'show_id': 59769},
#  {'id': 3326511,
#   'uri': 'https://api.kexp.org/v2/plays/3326511/',
#   'airdate': '2024-03-25T06:48:42-07:00',
#   'show': 59769,
#   'show_uri': 'https://api.kexp.org/v2/shows/59769/',
#   'image_uri': 'https://coverartarchive.org/release/ba398ba4-4e25-497c-9862-0ca3bbf4e75a/30426265187-500.jpg',
#   'thumbnail_uri': 'https://coverartarchive.org/release/ba398ba4-4e25-497c-9862-0ca3bbf4e75a/30426265187-250.jpg',
#   'song': '9 to 5',
#   'track_id': None,
#   'recording_id': '954e74db-edb5-43a7-bffc-b01684473cf1',
#   'artist': 'Dolly Parton',
#   'artist_ids': [],
#   'album': '9 to 5',
#   'release_id': None,
#   'release_group_id': None,
#   'labels': ['Atlantic'],
#   'label_ids': ['50c384a2-0b44-401b-b893-8181173339c7'],
#   'release_date': '1980-11-10',
#   'rotation_status': None,
#   'is_local': False,
#   'is_request': False,
#   'is_live': False,
#   'comment': 'By request for Jean!',
#   'play_type': 'trackplay',
#   'show_id': 59769},
#  {'id': 3326509,
#   'uri': 'https://api.kexp.org/v2/plays/3326509/',
#   'airdate': '2024-03-25T06:44:42-07:00',
#   'show': 59769,
#   'show_uri': 'https://api.kexp.org/v2/shows/59769/',
#   'image_uri': 'https://ia601203.us.archive.org/32/items/mbid-86a0216e-0562-4e9b-be75-4d0883977f4c/mbid-86a0216e-0562-4e9b-be75-4d0883977f4c-37519999944_thumb500.jpg',
#   'thumbnail_uri': 'https://ia801203.us.archive.org/32/items/mbid-86a0216e-0562-4e9b-be75-4d0883977f4c/mbid-86a0216e-0562-4e9b-be75-4d0883977f4c-37519999944_thumb250.jpg',
#   'song': 'Edge Of The Sun',
#   'track_id': '429c70c3-cab9-4a26-8fb2-8b280e810097',
#   'recording_id': '07d0fab0-9595-47e0-aba8-7a8154a0929c',
#   'artist': 'Gossip',
#   'artist_ids': ['0f96c38b-8e21-4571-afe0-cb11196a8acd'],
#   'album': 'Real Power',
#   'release_id': '86a0216e-0562-4e9b-be75-4d0883977f4c',
#   'release_group_id': 'acdf407e-e34e-4e25-bdcc-3d26fff792b9',
#   'labels': ['Columbia Local'],
#   'label_ids': ['d27f33f7-f22b-43a7-ac98-f789c258888a'],
#   'release_date': '2024-03-22',
#   'rotation_status': 'Medium',
#   'is_local': True,
#   'is_request': False,
#   'is_live': False,
#   'comment': 'New music from Portland-based Gossip! Their sixth album Real Power was just released! \n\nhttps://www.bethditto.com/',
#   'play_type': 'trackplay',
#   'show_id': 59769},
#  {'id': 3326508,
#   'uri': 'https://api.kexp.org/v2/plays/3326508/',
#   'airdate': '2024-03-25T06:41:16-07:00',
#   'show': 59769,
#   'show_uri': 'https://api.kexp.org/v2/shows/59769/',
#   'image_uri': 'https://ia801903.us.archive.org/15/items/mbid-dc48c6ad-ba1e-4e22-986d-0a37cbcbe21c/mbid-dc48c6ad-ba1e-4e22-986d-0a37cbcbe21c-26506951546_thumb500.jpg',
#   'thumbnail_uri': 'https://ia801903.us.archive.org/15/items/mbid-dc48c6ad-ba1e-4e22-986d-0a37cbcbe21c/mbid-dc48c6ad-ba1e-4e22-986d-0a37cbcbe21c-26506951546_thumb250.jpg',
#   'song': 'Wildfires',
#   'track_id': '5eab6569-c3e5-4a82-ad85-a34e9c512a72',
#   'recording_id': '2aebfb12-6452-44ac-ba1a-d9b7765bac54',
#   'artist': 'SAULT',
#   'artist_ids': ['23b19bc5-813e-4456-bbae-ac3ca118f535'],
#   'album': 'UNTITLED (Black Is)',
#   'release_id': 'dc48c6ad-ba1e-4e22-986d-0a37cbcbe21c',
#   'release_group_id': '3024784e-af94-4ff7-9755-d5df24556e37',
#   'labels': ['Forever Living Originals'],
#   'label_ids': ['81e61c90-28f2-4dcb-b656-cac924dfa331'],
#   'release_date': '2020-06-19',
#   'rotation_status': 'Library',
#   'is_local': False,
#   'is_request': False,
#   'is_live': False,
#   'comment': 'Enigmatic London collective SAULT\'s 2020 release \'Untitled (Black Is)\' was accompanied by a message from the band:\n\n"We present our first \'Untitled\' album to mark a moment in time where we as Black People, and of Black Origin are fighting for our lives. RIP George Floyd and all those who have suffered from police brutality and systemic racism. Change is happening… We are focused."\n\nhttps://saultglobal.bandcamp.com\nhttps://www.sault.global',
#   'play_type': 'trackplay',
#   'show_id': 59769},
#  {'id': 3326507,
#   'uri': 'https://api.kexp.org/v2/plays/3326507/',
#   'airdate': '2024-03-25T06:37:23-07:00',
#   'show': 59769,
#   'show_uri': 'https://api.kexp.org/v2/shows/59769/',
#   'image_uri': 'https://ia903003.us.archive.org/34/items/mbid-b56191a4-a8ca-42d9-b722-0db6d5ab858b/mbid-b56191a4-a8ca-42d9-b722-0db6d5ab858b-23923954436_thumb500.jpg',
#   'thumbnail_uri': 'https://ia803003.us.archive.org/34/items/mbid-b56191a4-a8ca-42d9-b722-0db6d5ab858b/mbid-b56191a4-a8ca-42d9-b722-0db6d5ab858b-23923954436_thumb250.jpg',
#   'song': 'Get Well',
#   'track_id': '7ea8aad0-f0f2-4adc-93e7-16b173b9d7d2',
#   'recording_id': '6b855421-2dc0-417e-8dbe-db1daf066a37',
#   'artist': 'Jay Som',
#   'artist_ids': ['3b910f7b-018f-408f-950b-47e02d2ce305'],
#   'album': 'Anak Ko',
#   'release_id': 'b56191a4-a8ca-42d9-b722-0db6d5ab858b',
#   'release_group_id': '19a15576-2027-497d-93e7-07c67879db0e',
#   'labels': ['Polyvinyl'],
#   'label_ids': ['2ad60482-164f-4e5c-ac78-1f5267d4fdc0'],
#   'release_date': '2019-08-23',
#   'rotation_status': 'Library',
#   'is_local': False,
#   'is_request': False,
#   'is_live': False,
#   'comment': 'Happy 30th birthday to Jay Som, aka Melina Mae Duterte, born on this day in 1994.\n\nJay Som spoke to KEXP\'s Dusty Henry about how she stopped drinking and its influence on "Anak Ko": \n\nhttps://www.kexp.org/read/2019/8/23/comfort-change-and-tenderness-jay-som-her-dazzling-new-album-anak-ko/',
#   'play_type': 'trackplay',
#   'show_id': 59769},
#  {'id': 3326506,
#   'uri': 'https://api.kexp.org/v2/plays/3326506/',
#   'airdate': '2024-03-25T06:34:28-07:00',
#   'show': 59769,
#   'show_uri': 'https://api.kexp.org/v2/shows/59769/',
#   'image_uri': 'https://ia801207.us.archive.org/7/items/mbid-6217d90e-9517-445c-9396-c7862ed2a143/mbid-6217d90e-9517-445c-9396-c7862ed2a143-37729521341_thumb500.jpg',
#   'thumbnail_uri': 'https://ia601207.us.archive.org/7/items/mbid-6217d90e-9517-445c-9396-c7862ed2a143/mbid-6217d90e-9517-445c-9396-c7862ed2a143-37729521341_thumb250.jpg',
#   'song': 'Crimes of the Heart',
#   'track_id': 'eba9eff3-1fdd-4352-8bbe-d6cf2132f498',
#   'recording_id': 'b1bbd36a-8b2d-4d7d-914a-92cc337062f2',
#   'artist': 'Waxahatchee',
#   'artist_ids': ['42321e24-42b6-4f08-b0d9-8325ee887a20'],
#   'album': 'Tigers Blood',
#   'release_id': '6217d90e-9517-445c-9396-c7862ed2a143',
#   'release_group_id': 'f9aa9b53-2c89-4901-926e-e992f1e4d8c0',
#   'labels': ['Anti‐'],
#   'label_ids': ['5b8cf470-f162-4ee3-9b9f-77ff4ee0c601'],
#   'release_date': '2024-03-22',
#   'rotation_status': 'Heavy',
#   'is_local': False,
#   'is_request': False,
#   'is_live': False,
#   'comment': "New from Waxahatchee!\n\nAlbum review from KEXP's Chris Sanley:\n\nWhen Katie Crutchfield entered her alt. country era with 2020’s Saint Cloud, it felt like an artist returning home. On Tigers Blood, her debut album for ANTI-, these Americana roots have firmly taken hold, delighting listeners with her specific vocal affect, just the right amount of twang, and a way with lyrical phrasing and storytelling that is so impactful. From up tempo rockers (Bored) to gut wrenching ballads (Right Back To It feat. MJ Lenderman) with memorable melodies and hooks to boot, the sixth album from Waxahatchee has all the makings of a timeless classic.",
#   'play_type': 'trackplay',
#   'show_id': 59769},
#  {'id': 3326505,
#   'uri': 'https://api.kexp.org/v2/plays/3326505/',
#   'airdate': '2024-03-25T06:32:42-07:00',
#   'show': 59769,
#   'show_uri': 'https://api.kexp.org/v2/shows/59769/',
#   'image_uri': '',
#   'thumbnail_uri': '',
#   'comment': '',
#   'play_type': 'airbreak',
#   'show_id': 59769}]
