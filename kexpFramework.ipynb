# %% [markdown]
# # KEXP Playlist Scraping
# **Michael Santoro - michael.santoro@du.edu**
# ## Introduction
# Being a big fan of KEXP and especially the morning show I am going to use the api found here to scrape song information from the show. https://api.kexp.org/v2/

# %%
import requests
import pandas as pd

# %%
r = requests.get('https://api.kexp.org/v2/')
r.status_code
# Out:
# 200

# %%
type(r.json())
# Out:
# dict

# %%
r.json()
# Out:
# {'hosts': 'https://api.kexp.org/v2/hosts/',
#  'programs': 'https://api.kexp.org/v2/programs/',
#  'shows': 'https://api.kexp.org/v2/shows/',
#  'plays': 'https://api.kexp.org/v2/plays/',
#  'timeslots': 'https://api.kexp.org/v2/timeslots/'}

# %% [markdown]
# ## DJ Research

# %%
hosts = requests.get('https://api.kexp.org/v2/hosts')

# %%
count = hosts.json()['count']

# %%
djs = {'name':[],
      'id':[],
      'is_active':[]}
for i in range(0,120,20):
    hosts = requests.get('https://api.kexp.org/v2/hosts/?offset='+f'{i}')
    for entry in hosts.json()['results']:
        djs['name'].append(entry['name'])
        djs['id'].append(entry['id'])
        djs['is_active'].append(entry['is_active'])
dj_df = pd.DataFrame(djs)

# %%
dj_df.shape
# Out:
# (91, 3)

# %%
dj_df.to_csv('djData.csv')

# %% [markdown]
# ## Programs Research

# %%
programs = requests.get('https://api.kexp.org/v2/programs')

# %%
programs.json()
# Out:
# {'count': 36,
#  'next': 'https://api.kexp.org/v2/programs/?limit=20&offset=20',
#  'previous': None,
#  'results': [{'id': 26,
#    'uri': 'https://api.kexp.org/v2/programs/26/',
#    'name': '90.TEEN',
#    'description': 'Rock,Eclectic,Variety Mix',
#    'tags': 'Rock,Eclectic,Variety Mix',
#    'is_active': True},
#   {'id': 1,
#    'uri': 'https://api.kexp.org/v2/programs/1/',
#    'name': 'Audioasis',
#    'description': "Audioasis is KEXP's long-running Northwest music show hosted by Sharlese Metcalf. Past hosts have included Jonathen Poneman, Jason Hughes, Scott Vanderpool, Stevie Zoom, Sean Nelson and Hannah Levin. John Richards helps produce the show. Audioasis delivers three hours of local and live bands from all areas and genres of the Northwest. On Audioasis, you'll hear the new, the old, the demos, the vinyl, and the future of music. Every first Saturday of the month you can catch Audioasis out in the city LIVE! Tune in Saturday from 6-9 PM.",
#    'tags': 'Rock,Eclectic,Pacific Northwest',
#    'is_active': True},
#   {'id': 27,
#    'uri': 'https://api.kexp.org/v2/programs/27/',
#    'name': 'Best Ambiance',
#    'description': 'Went off the air in 2011.',
#    'tags': 'African,World',
#    'is_active': False},
#   {'id': 33,
#    'uri': 'https://api.kexp.org/v2/programs/33/',
#    'name': 'Drive Time',
#    'description': '',
#    'tags': 'Rock,Eclectic,Variety Mix',
#    'is_active': True},
#   {'id': 32,
#    'uri': 'https://api.kexp.org/v2/programs/32/',
#    'name': 'Early',
#    'description': '',
#    'tags': 'Rock,Eclectic,Variety Mix',
#    'is_active': True},
#   {'id': 2,
#    'uri': 'https://api.kexp.org/v2/programs/2/',
#    'name': 'El Sonido',
#    'description': "El Sonido is a three hour trip around the diverse world of Latin music and culture from South, Central and North America, as well as Spain and the rest of the globe. \\n\\nThe focus is on new music and the growing Latin alternative scene, but traditional styles, both old and new are also regularly spotlighted. There's tons of fresh contemporary flavors to enjoy from hip-hop, nu-cumbia, indie-rock, reggaeton and dance punk to indie-folk, tropical bass, reggae, funk and more. Plus there’s an endless number of traditional styles too, you’ll hear bachata, tango, salsa, flamenco, norteño and dozens of others. \\n\\nMusicians and DJs from around the world will regularly stop by for exclusive live performances and I’ll keep you up-to-date with Latin music news and events. \\n\\nTune in every Monday evening and we’ll travel together, making new discoveries and having a blast along the way.",
#    'tags': 'Latin,World',
#    'is_active': True},
#   {'id': 3,
#    'uri': 'https://api.kexp.org/v2/programs/3/',
#    'name': 'Expansions',
#    'description': 'Expansions began in late 1995 as the brainchild of Riz Rollins as a response to the burgeoning acid jazz scene that was enjoying popularity in local clubs, but underexposed on the local airwaves. Even at its inception it has always been important that the show not be commanded by any monolithic style or single host, but has always enjoyed 3 hosts who bring a variety of influences and style to the final mix. An Expansions mix will include old and new releases in its mix in a variety of genres. An Expansions mix can included trip-hop, chill, ambient, drum and bass, house, dub, electronica, jazz, sometimes world music, sometimes rock, sometimes....well sometimes even the most disparate elements come together thanks to the expert curator efforts of its current hosts Kid Hops, Masa, and Riz. \\n\\n-DJ Riz',
#    'tags': 'Electronic',
#    'is_active': True},
#   {'id': 22,
#    'uri': 'https://api.kexp.org/v2/programs/22/',
#    'name': 'Friday Night',
#    'description': 'Electronic, Soul, R&B, Hip-Hop, Rock',
#    'tags': 'Rock,Eclectic,Variety Mix',
#    'is_active': True},
#   {'id': 4,
#    'uri': 'https://api.kexp.org/v2/programs/4/',
#    'name': 'Jazz Theatre',
#    'description': 'I have a personal mission statement in mind for Jazz Theater. That is, to really celebrate the fact that Jazz Is Alive and Thriving. Now! \\n\\nIn recent years, jazz has been cast in an unfortunate historical context -- as something that already happened, and is now over. Or, individual "experts" are too willing to narrowly define jazz - like; it sounds like this, and like that, and like this -- and if it doesn\'t, it isn\'t jazz. \\n\\nI think instead, that jazz, like any vibrant art form, has a mandate to expand and recreate itself -- to try new things, to get better, or at least to be different today than it was yesterday. Certainly jazz has a rich history. But part of that history is expansion and progression. Jazz never has stood still for long, there\'s no reason to think is should now. \\n\\nIn programming Jazz Theater I look for compelling work by artists who have been willing to blaze new trails. Clearly they have all studied the history of jazz, and thankfully they are not willing to be confined by it. Some of Jazz Theater will be familiar and, hopefully, some of it will be like nothing you\'ve ever heard before. \\n\\n-John Gilbreath',
#    'tags': 'Jazz',
#    'is_active': True},
#   {'id': 36,
#    'uri': 'https://api.kexp.org/v2/programs/36/',
#    'name': 'Live on KEXP',
#    'description': '',
#    'tags': 'Live,Eclectic,Variety Mix',
#    'is_active': True},
#   {'id': 34,
#    'uri': 'https://api.kexp.org/v2/programs/34/',
#    'name': 'Mechanical Breakdown',
#    'description': '',
#    'tags': 'Wave,Synth,Post Punk,EBM',
#    'is_active': True},
#   {'id': 5,
#    'uri': 'https://api.kexp.org/v2/programs/5/',
#    'name': 'Midnight in a Perfect World',
#    'description': 'Multi-genre program featuring eclectic sets by a rotating cast of international and local DJs, each building upon a party vibe to kick off your weekend.',
#    'tags': 'Eclectic,DJ,Variety Mix',
#    'is_active': True},
#   {'id': 6,
#    'uri': 'https://api.kexp.org/v2/programs/6/',
#    'name': 'Mind Over Matters',
#    'description': "Mind Over Matters carries a wide range of provocative speakers and guests who bring our listeners viewpoints not often heard in the corporate media. MOM focuses on today's most important social, political and economic issues giving voice to the people directly impacted and involved. By giving a forum to those not normally heard in corporate media, MOM offers a unique perspective on the issues that impact our daily lives. \\n\\nMOM carries a stellar list of nationally produced shows including Alternative Radio, Counterspin, Radio Nation, Making Contact and TUC Radio. We also carry several locally produced shows including The Sustainability Segment, Community Forum and Deep Water. \\n\\nSome of the unique voices you'll hear on MOM include Howard Zinn, Vandana Shiva, Noam Chomsky, David Korten, Molly Ivins, Greg Palast, Winona LaDuke, Robert McChesney, Ralph Nader, Arundhati Roy, Michael Moore, Naomi Klein and John Judge.",
#    'tags': 'Public Affairs',
#    'is_active': True},
#   {'id': 30,
#    'uri': 'https://api.kexp.org/v2/programs/30/',
#    'name': "Mo'Glo",
#    'description': 'Went off the air in 2011.',
#    'tags': 'World',
#    'is_active': False},
#   {'id': 35,
#    'uri': 'https://api.kexp.org/v2/programs/35/',
#    'name': 'Overnight Afrobeats',
#    'description': '',
#    'tags': 'Afrobeat',
#    'is_active': True},
#   {'id': 24,
#    'uri': 'https://api.kexp.org/v2/programs/24/',
#    'name': 'Pacific Notions',
#    'description': 'KEXP',
#    'tags': 'KEXP',
#    'is_active': True},
#   {'id': 7,
#    'uri': 'https://api.kexp.org/v2/programs/7/',
#    'name': 'Positive Vibrations',
#    'description': 'Placing equal legitimacy upon all styles of Jamaican musical expression, Positive Vibrations joins the dots between Ska, Rocksteady, Roots Reggae, Dub, and Dancehall. Kid Hops educates as he entertains - riding rhythms across artists, labels, and decades, he demystifies the connections between producers and studios. From the roughest riddims, to the sweetest harmonies and rudest of rudebwoy deejays, Positive Vibrations provides the perfect blend of Jamaican sounds.',
#    'tags': 'Reggae,World',
#    'is_active': True},
#   {'id': 8,
#    'uri': 'https://api.kexp.org/v2/programs/8/',
#    'name': "Preachin' the Blues",
#    'description': "From out of the swamp and through the woods comes the Preachin' the Blues show. Every Sunday I explore the downhome, uptown and gospel sounds of rhythm and blues music, and the focus is always on the most soulful, gritty, heartfelt and creative artists and material. \\n\\nCountry blues gets a special spotlight in the early morning, but quite often we move into the church for some old time singing, powerful preaching and funky accompaniment. \\n\\nI am a fan of southern soul and I always include something from my collection of Stax and Hi stuff in the mix, but the deep blues are firmly represented in each show with heaping helpings of the three Kings of the blues guitar, the rich character of Chicago's legends, and always a certain amount of Louisiana's magickal mystique. \\n\\n-Johnny Horn",
#    'tags': 'Blues,Country,Roots',
#    'is_active': True},
#   {'id': 9,
#    'uri': 'https://api.kexp.org/v2/programs/9/',
#    'name': 'Seek & Destroy',
#    'description': 'Tanner Ellison : Host, DJ, and Producer of Seek & Destroy, Saturday Nights at Midnight to 2AM<br /><br /> Tanner Ellison is a professional artist living and working in Seattle. He has been corrupted by metal since he was a little grub. He had an unlikely start in radio around the age of 12 or 13 when he had a local mechanic build a FM transmitter for trade and started his hometowns only pirate radio station. Running a pirate radio station with his hooligan friends eventually led to writing and playing music. Tanner played guitar and screeched in many terrible punk and metal bands over the years. After moving to Seattle, he guest DJ\'ed for KEXP\'s Sonic Reducer as well as several venues and events.<br /><br /> Tanner has sought out every blackened forest and gruesome abbitoir of the underground extreme metal world seeking incredible music. He grew up loving everything from old school death metal to the most atmospheric, ethereal black metal to haunt the the Pacific Northwest. Tanner has a rabid affection for listening to records and tapes and plays mostly vinyl every week on Seek & Destroy to ensure the best possible sound quality for listeners.<br /><br /> When not sharpening battle axes and hanging out in spooky caves, he sculpts and models undead soldiers from beyond the void and draws pictures of dragons and space wizards. He is currently a Senior Production Artist at HBO making all kinds of rad stuff.<br /><br /> Facebook - <a href="https://www.facebook.com/SeekAndDestroyOnKEXP" target="_blank">https://www.facebook.com/SeekAndDestroyOnKEXP</a><br />Instagram - <a href="https://instagram.com/seekanddestroy_kexp" target="_blank">https://instagram.com/seekanddestroy_kexp</a>',
#    'tags': 'Metal,Rock',
#    'is_active': True},
#   {'id': 19,
#    'uri': 'https://api.kexp.org/v2/programs/19/',
#    'name': 'Shake the Shack',
#    'description': 'Went off the air in 2018.',
#    'tags': 'Rockabilly,Blues,Country,Roots',
#    'is_active': False}]}

# %%
programs.json()['count']
# Out:
# 36

# %%
programs = {'name':[],
      'id':[],
      'description':[],
      'tags':[],
      'is_active':[]}
for i in range(0,60,20):
    prog = requests.get(f'https://api.kexp.org/v2/programs/?offset={i}')
    for entry in prog.json()['results']:
        programs['name'].append(entry['name'])
        programs['id'].append(entry['id'])
        programs['description'].append(entry['description'])
        programs['tags'].append(entry['tags'])
        programs['is_active'].append(entry['is_active'])
programs_df = pd.DataFrame(programs)

# %%
programs_df
# Out:
#                            name  id  \
# 0                       90.TEEN  26
# 1                     Audioasis   1
# 2                 Best Ambiance  27
# 3                    Drive Time  33
# 4                         Early  32
# 5                     El Sonido   2
# 6                    Expansions   3
# 7                  Friday Night  22
# 8                  Jazz Theatre   4
# 9                  Live on KEXP  36
# 10         Mechanical Breakdown  34
# 11  Midnight in a Perfect World   5
# 12            Mind Over Matters   6
# 13                       Mo'Glo  30
# 14          Overnight Afrobeats  35
# 15              Pacific Notions  24
# 16          Positive Vibrations   7
# 17          Preachin' the Blues   8
# 18               Seek & Destroy   9
# 19              Shake the Shack  19
# 20                     Sonarchy  10
# 21                Sonic Reducer  11
# 22               Sound & Vision  25
# 23                Street Sounds  12
# 24                  Sunday Soul  21
# 25               Swingin' Doors  13
# 26                 Test Program  31
# 27           The Afternoon Show  14
# 28              The Midday Show  15
# 29             The Morning Show  16
# 30                The Roadhouse  23
# 31            To The 5 Boroughs  29
# 32             Under The Needle  17
# 33                  Variety Mix  18
# 34                      Wake Up  28
# 35                      Wo' Pop  20
#
#                                           description  \
# 0                           Rock,Eclectic,Variety Mix
# 1   Audioasis is KEXP's long-running Northwest mus...
# 2                           Went off the air in 2011.
# 3
# 4
# 5   El Sonido is a three hour trip around the dive...
# 6   Expansions began in late 1995 as the brainchil...
# 7                Electronic, Soul, R&B, Hip-Hop, Rock
# 8   I have a personal mission statement in mind fo...
# 9
# 10
# 11  Multi-genre program featuring eclectic sets by...
# 12  Mind Over Matters carries a wide range of prov...
# 13                          Went off the air in 2011.
# 14
# 15                                               KEXP
# 16  Placing equal legitimacy upon all styles of Ja...
# 17  From out of the swamp and through the woods co...
# 18  Tanner Ellison : Host, DJ, and Producer of See...
# 19                          Went off the air in 2018.
# 20  Sonarchy Radio is a live performance broadcast...
# 21  Sonic Reducer brings you three hours of the be...
# 22                                               KEXP
# 23  Streetsounds is Seattle's longest running mixs...
# 24                           Soul, R&B, Funk, Hip-Hop
# 25  Swingin' Doors is dedicated to a wide range of...
# 26                                       Test program
# 27  KEXP Radio hand selects all of its music, with...
# 28  KEXP Radio hand selects all of its music, with...
# 29  KEXP Radio hand selects all of its music, with...
# 30  The Roadhouse is a roots program emphasizing t...
# 31                          Went off the air in 2011.
# 32  Live Music recorded locally and distributed ar...
# 33  KEXP Radio hand selects all of its music, with...
# 34                          Went off the air in 2011.
# 35  Wo-Pop is a 3 hour look into what used to be c...
#
#                                  tags  is_active
# 0           Rock,Eclectic,Variety Mix       True
# 1     Rock,Eclectic,Pacific Northwest       True
# 2                       African,World      False
# 3           Rock,Eclectic,Variety Mix       True
# 4           Rock,Eclectic,Variety Mix       True
# 5                         Latin,World       True
# 6                          Electronic       True
# 7           Rock,Eclectic,Variety Mix       True
# 8                                Jazz       True
# 9           Live,Eclectic,Variety Mix       True
# 10           Wave,Synth,Post Punk,EBM       True
# 11            Eclectic,DJ,Variety Mix       True
# 12                     Public Affairs       True
# 13                              World      False
# 14                           Afrobeat       True
# 15                               KEXP       True
# 16                       Reggae,World       True
# 17                Blues,Country,Roots       True
# 18                         Metal,Rock       True
# 19     Rockabilly,Blues,Country,Roots      False
# 20     Experimental,Pacific Northwest       True
# 21                          Punk,Rock       True
# 22                               KEXP       True
# 23                            Hip Hop       True
# 24          Rock,Eclectic,Variety Mix       True
# 25                Blues,Country,Roots       True
# 26          Rock,Eclectic,Variety Mix      False
# 27          Rock,Eclectic,Variety Mix       True
# 28          Rock,Eclectic,Variety Mix       True
# 29          Rock,Eclectic,Variety Mix       True
# 30                Blues,Country,Roots       True
# 31          Rock,Eclectic,Variety Mix      False
# 32  Live Music, Eclectic, Variety Mix       True
# 33          Rock,Eclectic,Variety Mix       True
# 34          Rock,Eclectic,Variety Mix      False
# 35                   Electronic,World       True

# %%
programs_df.to_csv('programData.csv')

# %% [markdown]
# ## Show Research

# %%
shows = requests.get('https://api.kexp.org/v2/shows/')

# %%
shows.json()['results'][0]
# Out:
# {'id': 54494,
#  'uri': 'https://api.kexp.org/v2/shows/54494/',
#  'program': 14,
#  'program_uri': 'https://api.kexp.org/v2/programs/14/',
#  'hosts': [55],
#  'host_uris': ['https://api.kexp.org/v2/hosts/55/'],
#  'program_name': 'The Afternoon Show',
#  'program_tags': 'Rock,Eclectic,Variety Mix',
#  'host_names': ['Larry Mizell, Jr.'],
#  'tagline': 'Happy Friday!',
#  'image_uri': 'https://www.kexp.org/media/filer_public/5e/ed/5eed57ed-2169-45b8-8605-266712b6eee3/larry_mizell_jr_thumbnail.png',
#  'start_time': '2022-08-12T12:59:26-07:00'}

# %% [markdown]
# ***Shows will need to be requerried as data is forever updated.***</br>
# My plan is to pull data by year, for testing I will start with last year.

# %%
shows = requests.get('https://api.kexp.org/v2/shows/?start_time_after=2021-01-01T00:00:00&start_time_before=2022-01-01T00:00:00')

# %%
shows.json()['count']
# Out:
# 3288

# %%
showsDict = {'id':[],
             'program_id':[],
             'hosts_ids':[],
             'program_name':[],
             'start_time':[]}
for i in range(0,3300,20):
    print(f'fetching: {i}')
    shows = requests.get(f'https://api.kexp.org/v2/shows/?start_time_after=2021-01-01T00:00:00&start_time_before=2022-01-01T00:00:00&offset={i}')
    for entry in shows.json()['results']:
        showsDict['id'].append(entry['id'])
        showsDict['program_id'].append(entry['program'])
        showsDict['hosts_ids'].append(entry['hosts'])
        showsDict['program_name'].append(entry['program_name'])
        showsDict['start_time'].append(entry['start_time'])
shows_df = pd.DataFrame(showsDict)
# Out:
# fetching: 0
# fetching: 20
# fetching: 40
# fetching: 60
# fetching: 80
# fetching: 100
# fetching: 120
# fetching: 140
# fetching: 160
# fetching: 180
# fetching: 200
# fetching: 220
# fetching: 240
# fetching: 260
# fetching: 280
# fetching: 300
# fetching: 320
# fetching: 340
# fetching: 360
# fetching: 380
# fetching: 400
# fetching: 420
# fetching: 440
# fetching: 460
# fetching: 480
# fetching: 500
# fetching: 520
# fetching: 540
# fetching: 560
# fetching: 580
# fetching: 600
# fetching: 620
# fetching: 640
# fetching: 660
# fetching: 680
# fetching: 700
# fetching: 720
# fetching: 740
# fetching: 760
# fetching: 780
# fetching: 800
# fetching: 820
# fetching: 840
# fetching: 860
# fetching: 880
# fetching: 900
# fetching: 920
# fetching: 940
# fetching: 960
# fetching: 980
# fetching: 1000
# fetching: 1020
# fetching: 1040
# fetching: 1060
# fetching: 1080
# fetching: 1100
# fetching: 1120
# fetching: 1140
# fetching: 1160
# fetching: 1180
# fetching: 1200
# fetching: 1220
# fetching: 1240
# fetching: 1260
# fetching: 1280
# fetching: 1300
# fetching: 1320
# fetching: 1340
# fetching: 1360
# fetching: 1380
# fetching: 1400
# fetching: 1420
# fetching: 1440
# fetching: 1460
# fetching: 1480
# fetching: 1500
# fetching: 1520
# fetching: 1540
# fetching: 1560
# fetching: 1580
# fetching: 1600
# fetching: 1620
# fetching: 1640
# fetching: 1660
# fetching: 1680
# fetching: 1700
# fetching: 1720
# fetching: 1740
# fetching: 1760
# fetching: 1780
# fetching: 1800
# fetching: 1820
# fetching: 1840
# fetching: 1860
# fetching: 1880
# fetching: 1900
# fetching: 1920
# fetching: 1940
# fetching: 1960
# fetching: 1980
# fetching: 2000
# fetching: 2020
# fetching: 2040
# fetching: 2060
# fetching: 2080
# fetching: 2100
# fetching: 2120
# fetching: 2140
# fetching: 2160
# fetching: 2180
# fetching: 2200
# fetching: 2220
# fetching: 2240
# fetching: 2260
# fetching: 2280
# fetching: 2300
# fetching: 2320
# fetching: 2340
# fetching: 2360
# fetching: 2380
# fetching: 2400
# fetching: 2420
# fetching: 2440
# fetching: 2460
# fetching: 2480
# fetching: 2500
# fetching: 2520
# fetching: 2540
# fetching: 2560
# fetching: 2580
# fetching: 2600
# fetching: 2620
# fetching: 2640
# fetching: 2660
# fetching: 2680
# fetching: 2700
# fetching: 2720
# fetching: 2740
# fetching: 2760
# fetching: 2780
# fetching: 2800
# fetching: 2820
# fetching: 2840
# fetching: 2860
# fetching: 2880
# fetching: 2900
# fetching: 2920
# fetching: 2940
# fetching: 2960
# fetching: 2980
# fetching: 3000
# fetching: 3020
# fetching: 3040
# fetching: 3060
# fetching: 3080
# fetching: 3100
# fetching: 3120
# fetching: 3140
# fetching: 3160
# fetching: 3180
# fetching: 3200
# fetching: 3220
# fetching: 3240
# fetching: 3260
# fetching: 3280

# %%
shows_df
# Out:
#          id  program_id hosts_ids        program_name  \
# 0     52491          12      [87]       Street Sounds
# 1     52490          12      [87]       Street Sounds
# 2     52489          12      [87]       Street Sounds
# 3     52488          22      [53]        Friday Night
# 4     52486          33      [50]          Drive Time
# ...     ...         ...       ...                 ...
# 3283  49207          14      [50]  The Afternoon Show
# 3284  49206          15       [4]     The Midday Show
# 3285  49205          16      [19]    The Morning Show
# 3286  49204          32      [11]               Early
# 3287  49203          18       [2]         Variety Mix
#
#                      start_time
# 0     2021-12-31T22:00:41-08:00
# 1     2021-12-31T22:00:23-08:00
# 2     2021-12-31T21:59:26-08:00
# 3     2021-12-31T19:01:00-08:00
# 4     2021-12-31T16:05:00-08:00
# ...                         ...
# 3283  2021-01-01T13:01:29-08:00
# 3284  2021-01-01T10:00:08-08:00
# 3285  2021-01-01T07:01:28-08:00
# 3286  2021-01-01T05:00:57-08:00
# 3287  2021-01-01T01:03:55-08:00
#
# [3288 rows x 5 columns]

# %%
shows_df.to_csv('showsData_2021.csv')

# %%
shows_df[shows_df.program_name=='The Morning Show']
# Out:
#          id  program_id hosts_ids      program_name                 start_time
# 8     52483          16       [1]  The Morning Show  2021-12-31T07:02:44-08:00
# 16    52475          16       [1]  The Morning Show  2021-12-30T07:02:37-08:00
# 24    52467          16      [43]  The Morning Show  2021-12-29T07:03:28-08:00
# 32    52459          16      [90]  The Morning Show  2021-12-28T07:02:31-08:00
# 40    52451          16      [44]  The Morning Show  2021-12-27T07:00:08-08:00
# ...     ...         ...       ...               ...                        ...
# 3231  49259          16      [43]  The Morning Show  2021-01-07T07:01:14-08:00
# 3239  49251          16      [43]  The Morning Show  2021-01-06T07:00:51-08:00
# 3247  49243          16      [43]  The Morning Show  2021-01-05T07:00:44-08:00
# 3255  49235          16      [43]  The Morning Show  2021-01-04T07:00:02-08:00
# 3285  49205          16      [19]  The Morning Show  2021-01-01T07:01:28-08:00
#
# [268 rows x 5 columns]

# %% [markdown]
# ## Plays Research

# %%
shows_df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [1], in <cell line: 1>()
# ----> 1 shows_df
#
# NameError: name 'shows_df' is not defined

# %%
https://api.kexp.org/v2/plays/?show_ids=52475

# %% [markdown]
# Filters for Ref: https://api.kexp.org/v2/plays/?airdate_after=&airdate_before=&has_comment=&exclude_airbreaks=&show_ids=&host_ids=&song=&song_exact=&artist=&artist_exact=&album=&album_exact=&label=&label_exact=&recording_id=&ordering=

# %%
plays = requests.get(r'https://api.kexp.org/v2/plays/',params={'airdate_after':r'2022-08-10T07:00:00-07:00', 'airdate_before':r'2022-08-10T08:00:00-07:00'})

# %%
plays.json()
# Out:
# {'next': 'https://api.kexp.org/v2/plays/?airdate_after=2022-08-10T07%3A00%3A00-07%3A00&airdate_before=2022-08-10T08%3A00%3A00-07%3A00&limit=20&offset=20',
#  'previous': None,
#  'results': [{'id': 3076290,
#    'uri': 'https://api.kexp.org/v2/plays/3076290/',
#    'airdate': '2022-08-10T07:58:07-07:00',
#    'show': 54475,
#    'show_uri': 'https://api.kexp.org/v2/shows/54475/',
#    'image_uri': '',
#    'thumbnail_uri': '',
#    'comment': '',
#    'play_type': 'airbreak'},
#   {'id': 3076289,
#    'uri': 'https://api.kexp.org/v2/plays/3076289/',
#    'airdate': '2022-08-10T07:53:41-07:00',
#    'show': 54475,
#    'show_uri': 'https://api.kexp.org/v2/shows/54475/',
#    'image_uri': 'https://ia600904.us.archive.org/23/items/mbid-8838d557-42df-4ebd-88a4-f74cbc33e8f8/mbid-8838d557-42df-4ebd-88a4-f74cbc33e8f8-22584905643_thumb500.jpg',
#    'thumbnail_uri': 'https://ia800904.us.archive.org/23/items/mbid-8838d557-42df-4ebd-88a4-f74cbc33e8f8/mbid-8838d557-42df-4ebd-88a4-f74cbc33e8f8-22584905643_thumb250.jpg',
#    'song': 'In Circles',
#    'track_id': '6821cd55-295f-3ad0-b507-21784acbb711',
#    'recording_id': '91872a9f-6640-401c-8b9c-4cb8241f3e1e',
#    'artist': 'Sunny Day Real Estate',
#    'artist_ids': ['86b24e8f-a4d9-4c84-83ee-fde0d14ad9fa'],
#    'album': 'Diary',
#    'release_id': '8838d557-42df-4ebd-88a4-f74cbc33e8f8',
#    'release_group_id': '12e88251-2cde-3bea-9cee-2d8c7fe65039',
#    'labels': ['Sub Pop Records'],
#    'label_ids': ['38dc88de-7720-4100-9d5b-3cdc41b0c474'],
#    'release_date': '1994-05-10',
#    'rotation_status': None,
#    'is_local': True,
#    'is_request': False,
#    'is_live': False,
#    'comment': 'Diary is the debut studio album by American rock band Sunny Day Real Estate, released in 1994.\n---\nSunny Day Real Estate will be performing at the Moore Theatre on December 17th & 18th! https://www.sunnyday.realestate/\n---\nCelebrating the music of 1994 & 50 years of KEXP! - https://www.kexp.org/50',
#    'play_type': 'trackplay'},
#   {'id': 3076288,
#    'uri': 'https://api.kexp.org/v2/plays/3076288/',
#    'airdate': '2022-08-10T07:51:37-07:00',
#    'show': 54475,
#    'show_uri': 'https://api.kexp.org/v2/shows/54475/',
#    'image_uri': 'https://ia601904.us.archive.org/20/items/mbid-1d772217-d41e-41fc-8077-76f8cc556e46/mbid-1d772217-d41e-41fc-8077-76f8cc556e46-26378942154_thumb500.jpg',
#    'thumbnail_uri': 'https://ia801904.us.archive.org/20/items/mbid-1d772217-d41e-41fc-8077-76f8cc556e46/mbid-1d772217-d41e-41fc-8077-76f8cc556e46-26378942154_thumb250.jpg',
#    'song': 'Come On',
#    'track_id': '100b7f59-7cd8-369d-b268-798513519dbd',
#    'recording_id': '77e10c79-2d02-4d66-8cc7-6a588de9934d',
#    'artist': 'The Jesus and Mary Chain',
#    'artist_ids': ['e938a15c-b17e-4e7a-9f68-ff0d536cab44'],
#    'album': 'Stoned & Dethroned',
#    'release_id': '1d772217-d41e-41fc-8077-76f8cc556e46',
#    'release_group_id': 'b1726b94-8e1b-301e-a825-38da17ddb1d8',
#    'labels': ['American Recordings'],
#    'label_ids': ['f5be9cfe-e1af-405c-a074-caeaed6797c0'],
#    'release_date': '1994-08-23',
#    'rotation_status': None,
#    'is_local': False,
#    'is_request': False,
#    'is_live': False,
#    'comment': 'Stoned & Dethroned is the fifth studio album by the Scottish alternative rock band The Jesus and Mary Chain, released in 1994.\n---\nCelebrating the music of 1994 & 50 years of KEXP!',
#    'play_type': 'trackplay'},
#   {'id': 3076286,
#    'uri': 'https://api.kexp.org/v2/plays/3076286/',
#    'airdate': '2022-08-10T07:48:34-07:00',
#    'show': 54475,
#    'show_uri': 'https://api.kexp.org/v2/shows/54475/',
#    'image_uri': 'https://coverartarchive.org/release/1617a8bf-0751-45f9-8bee-0825b518092a/7422756243-500.jpg',
#    'thumbnail_uri': 'https://coverartarchive.org/release/1617a8bf-0751-45f9-8bee-0825b518092a/7422756243-250.jpg',
#    'song': 'Supernova',
#    'track_id': None,
#    'recording_id': 'f2e6a79a-efae-415b-879f-81af69208061',
#    'artist': 'Liz Phair',
#    'artist_ids': ['149326c2-b8a3-48e3-b3d2-9b5b9593127f'],
#    'album': 'Whip‐Smart',
#    'release_id': None,
#    'release_group_id': 'a5d5a8db-333e-3db4-9261-dd2815688489',
#    'labels': [],
#    'label_ids': [],
#    'release_date': '1994-09-15',
#    'rotation_status': None,
#    'is_local': False,
#    'is_request': False,
#    'is_live': False,
#    'comment': 'Whip-Smart is the second album by Liz Phair, released in 1994.\n---\nHappy 1994 & 50 years of KEXP! - https://www.kexp.org/50',
#    'play_type': 'trackplay'},
#   {'id': 3076285,
#    'uri': 'https://api.kexp.org/v2/plays/3076285/',
#    'airdate': '2022-08-10T07:45:38-07:00',
#    'show': 54475,
#    'show_uri': 'https://api.kexp.org/v2/shows/54475/',
#    'image_uri': 'https://ia600405.us.archive.org/19/items/mbid-0021f266-489a-33a8-b91f-506e37b6385d/mbid-0021f266-489a-33a8-b91f-506e37b6385d-15755743126_thumb500.jpg',
#    'thumbnail_uri': 'https://ia800405.us.archive.org/19/items/mbid-0021f266-489a-33a8-b91f-506e37b6385d/mbid-0021f266-489a-33a8-b91f-506e37b6385d-15755743126_thumb250.jpg',
#    'song': 'Kiss Chase',
#    'track_id': '79350e3d-71eb-330a-8bb6-a81277670e9b',
#    'recording_id': '6425b115-4616-4c5f-a46e-9a6d3fd850bb',
#    'artist': 'Lush',
#    'artist_ids': ['697801d1-68b2-4413-a7e4-0ef507d21cc1'],
#    'album': 'Split',
#    'release_id': 'ce67f98a-bfa7-43f7-88fa-38a9df8835c8',
#    'release_group_id': '150b59e4-9f69-31e9-b6ae-f05512b71580',
#    'labels': ['Reprise Records', '4AD'],
#    'label_ids': ['af6d6f49-2b4d-40fe-86d4-241906772b59',
#     'a539bb1e-f2e1-4b45-9db8-8053841e7503'],
#    'release_date': '1994-06-14',
#    'rotation_status': None,
#    'is_local': False,
#    'is_request': False,
#    'is_live': False,
#    'comment': 'Split is the third studio album by English rock band Lush, released in 1994.\n---\nHappy 1994 & 50 years of KEXP! - https://www.kexp.org/50/',
#    'play_type': 'trackplay'},
#   {'id': 3076284,
#    'uri': 'https://api.kexp.org/v2/plays/3076284/',
#    'airdate': '2022-08-10T07:41:40-07:00',
#    'show': 54475,
#    'show_uri': 'https://api.kexp.org/v2/shows/54475/',
#    'image_uri': 'https://ia804502.us.archive.org/33/items/mbid-0622f867-2f28-38eb-a295-7c20fd2b2292/mbid-0622f867-2f28-38eb-a295-7c20fd2b2292-7915360989_thumb500.jpg',
#    'thumbnail_uri': 'https://ia904502.us.archive.org/33/items/mbid-0622f867-2f28-38eb-a295-7c20fd2b2292/mbid-0622f867-2f28-38eb-a295-7c20fd2b2292-7915360989_thumb250.jpg',
#    'song': 'What’s the Frequency, Kenneth?',
#    'track_id': '27f04bb4-fed1-30b7-8527-38057e99f0f2',
#    'recording_id': '1bd27385-0fba-4a56-b217-73f8cdc41375',
#    'artist': 'R.E.M.',
#    'artist_ids': ['ea4dfa26-f633-4da6-a52a-f49ea4897b58'],
#    'album': 'Monster',
#    'release_id': '0622f867-2f28-38eb-a295-7c20fd2b2292',
#    'release_group_id': '2a71baeb-0c95-3d3a-aef9-8d5fe17a8038',
#    'labels': ['Warner Bros. Records', 'Columbia House'],
#    'label_ids': ['c595c289-47ce-4fba-b999-b87503e8cb71',
#     '0b6073f1-78a5-4078-bc01-22d7b05d0b7a'],
#    'release_date': '1994-09-27',
#    'rotation_status': None,
#    'is_local': False,
#    'is_request': False,
#    'is_live': False,
#    'comment': '"What\'s the Frequency, Kenneth?" by R.E.M. is from their ninth studio album, Monster (1994). The song\'s title refers to an incident in New York City in 1986, when two then-unknown assailants attacked journalist Dan Rather, while repeating "Kenneth, what is the frequency?"\n---\nCelebrating the music of 1994 & 50 years of KEXP! - https://www.kexp.org/50/',
#    'play_type': 'trackplay'},
#   {'id': 3076283,
#    'uri': 'https://api.kexp.org/v2/plays/3076283/',
#    'airdate': '2022-08-10T07:40:36-07:00',
#    'show': 54475,
#    'show_uri': 'https://api.kexp.org/v2/shows/54475/',
#    'image_uri': '',
#    'thumbnail_uri': '',
#    'comment': '',
#    'play_type': 'airbreak'},
#   {'id': 3076282,
#    'uri': 'https://api.kexp.org/v2/plays/3076282/',
#    'airdate': '2022-08-10T07:37:47-07:00',
#    'show': 54475,
#    'show_uri': 'https://api.kexp.org/v2/shows/54475/',
#    'image_uri': 'https://ia802704.us.archive.org/0/items/mbid-a0266c72-5a82-4c18-b156-7ca4d4c9308e/mbid-a0266c72-5a82-4c18-b156-7ca4d4c9308e-1952651246_thumb500.jpg',
#    'thumbnail_uri': 'https://ia802704.us.archive.org/0/items/mbid-a0266c72-5a82-4c18-b156-7ca4d4c9308e/mbid-a0266c72-5a82-4c18-b156-7ca4d4c9308e-1952651246_thumb250.jpg',
#    'song': 'Your Ghost',
#    'track_id': '052380ca-a32d-3e17-a62c-528884ff8988',
#    'recording_id': 'c4d997a2-9675-4d64-9a80-e556d4b048e8',
#    'artist': 'Kristin Hersh',
#    'artist_ids': ['0b461f11-c7af-4ddb-a30e-5cb0aabb3e7f'],
#    'album': 'Hips and Makers',
#    'release_id': '95a9a3fb-1257-365e-a807-1695333a8c34',
#    'release_group_id': '55e5d5c7-ad75-3c6d-bfff-cb8a65d177d7',
#    'labels': ['Sire Records'],
#    'label_ids': ['be0fec81-5c18-4494-8bbf-0d81dec006bf'],
#    'release_date': '1994-02-01',
#    'rotation_status': None,
#    'is_local': False,
#    'is_request': False,
#    'is_live': False,
#    'comment': '"Your Ghost" is the first track from Kristin Hersh\'s debut solo studio album Hips and Makers, released in 1994. It features additional backing vocals from Michael Stipe.\n---\nHappy 1994 & 50 years of music on KEXP! - https://www.kexp.org/50/',
#    'play_type': 'trackplay'},
#   {'id': 3076281,
#    'uri': 'https://api.kexp.org/v2/plays/3076281/',
#    'airdate': '2022-08-10T07:33:31-07:00',
#    'show': 54475,
#    'show_uri': 'https://api.kexp.org/v2/shows/54475/',
#    'image_uri': 'https://ia802908.us.archive.org/23/items/mbid-fd602828-6228-482e-8b92-fbee95ef7e84/mbid-fd602828-6228-482e-8b92-fbee95ef7e84-27179856488_thumb500.jpg',
#    'thumbnail_uri': 'https://ia802908.us.archive.org/23/items/mbid-fd602828-6228-482e-8b92-fbee95ef7e84/mbid-fd602828-6228-482e-8b92-fbee95ef7e84-27179856488_thumb250.jpg',
#    'song': 'The River Rise',
#    'track_id': '322ef7ea-8df9-30cf-998c-070061443c64',
#    'recording_id': 'a9328917-cef1-4a46-9552-0805674d3fea',
#    'artist': 'Mark Lanegan',
#    'artist_ids': ['a9126556-f555-4920-9617-6e013f8228a7'],
#    'album': 'Whiskey for the Holy Ghost',
#    'release_id': 'fd602828-6228-482e-8b92-fbee95ef7e84',
#    'release_group_id': 'c1a87165-1b1e-385b-87b3-568d45f29f28',
#    'labels': ['Sub Pop Records'],
#    'label_ids': ['38dc88de-7720-4100-9d5b-3cdc41b0c474'],
#    'release_date': '1994-01-08',
#    'rotation_status': None,
#    'is_local': True,
#    'is_request': False,
#    'is_live': False,
#    'comment': 'Whiskey for the Holy Ghost is the second solo album by former Screaming Trees vocalist Mark Lanegan, released in 1994.\n---\nCelebrating 1994 & 50 years of KEXP! - https://www.kexp.org/50',
#    'play_type': 'trackplay'},
#   {'id': 3076280,
#    'uri': 'https://api.kexp.org/v2/plays/3076280/',
#    'airdate': '2022-08-10T07:30:50-07:00',
#    'show': 54475,
#    'show_uri': 'https://api.kexp.org/v2/shows/54475/',
#    'image_uri': 'https://coverartarchive.org/release/c584b0c1-4073-40ef-8b52-d45f9bda8d16/10023501405-500.jpg',
#    'thumbnail_uri': 'https://coverartarchive.org/release/c584b0c1-4073-40ef-8b52-d45f9bda8d16/10023501405-250.jpg',
#    'song': 'Streets of Philadelphia',
#    'track_id': None,
#    'recording_id': '6b2b5d68-eb5b-4667-b87e-0bcdd6dc7477',
#    'artist': 'Bruce Springsteen',
#    'artist_ids': ['70248960-cb53-4ea4-943a-edb18f7d336f'],
#    'album': 'Philadelphia: Music From the Motion Picture',
#    'release_id': None,
#    'release_group_id': '235d0ed1-8889-4174-8383-c4725ea22741',
#    'labels': [],
#    'label_ids': [],
#    'release_date': '1994-01-01',
#    'rotation_status': None,
#    'is_local': False,
#    'is_request': False,
#    'is_live': False,
#    'comment': 'This won the Oscar for Best Original Song in 1994, beating out Neil Young\'s "Philadelphia," which was also written for the movie. Tom Hanks won his first Best Actor Oscar for his role in the movie. - https://bit.ly/3JNNCyO\n---\nCelebrating the music of 1994 & 50 years of music on KEXP! - https://www.kexp.org/50/',
#    'play_type': 'trackplay'},
#   {'id': 3076278,
#    'uri': 'https://api.kexp.org/v2/plays/3076278/',
#    'airdate': '2022-08-10T07:23:45-07:00',
#    'show': 54475,
#    'show_uri': 'https://api.kexp.org/v2/shows/54475/',
#    'image_uri': 'https://coverartarchive.org/release/8ec7bce7-27ee-3144-a52b-b5bd765860c5/2714350967-500.jpg',
#    'thumbnail_uri': 'https://coverartarchive.org/release/8ec7bce7-27ee-3144-a52b-b5bd765860c5/2714350967-250.jpg',
#    'song': 'Protection',
#    'track_id': None,
#    'recording_id': '9e599661-19a1-4941-958b-5d66e0da5c79',
#    'artist': 'Massive Attack',
#    'artist_ids': ['10adbe5e-a2c0-4bf3-8249-2b4cbf6e6ca8'],
#    'album': 'Protection',
#    'release_id': None,
#    'release_group_id': 'ded46e46-788d-3c1f-b21b-9f5e9c37b1bc',
#    'labels': [],
#    'label_ids': [],
#    'release_date': '1994-09-26',
#    'rotation_status': None,
#    'is_local': False,
#    'is_request': False,
#    'is_live': False,
#    'comment': '"Protection" is a collaboration between Massive Attack and Everything but the Girl singer Tracey Thorn that appears on Massive Attack\'s second studio album, released in 1994.\n---\nCelebrating 1994 & 50 years of KEXP! - https://www.kexp.org/50/',
#    'play_type': 'trackplay'},
#   {'id': 3076276,
#    'uri': 'https://api.kexp.org/v2/plays/3076276/',
#    'airdate': '2022-08-10T07:20:19-07:00',
#    'show': 54475,
#    'show_uri': 'https://api.kexp.org/v2/shows/54475/',
#    'image_uri': '',
#    'thumbnail_uri': '',
#    'comment': '',
#    'play_type': 'airbreak'},
#   {'id': 3076275,
#    'uri': 'https://api.kexp.org/v2/plays/3076275/',
#    'airdate': '2022-08-10T07:15:53-07:00',
#    'show': 54475,
#    'show_uri': 'https://api.kexp.org/v2/shows/54475/',
#    'image_uri': '',
#    'thumbnail_uri': '',
#    'song': "Screenwriter's Blues (clean album version)",
#    'track_id': 'b5db5c4a-00bc-445b-8c84-9b454d2a8ea4',
#    'recording_id': '20147d5c-4309-4019-b368-3cfd11ce96d8',
#    'artist': 'Soul Coughing',
#    'artist_ids': ['8067c102-4996-42bc-9980-06ce2e644eae'],
#    'album': "Screenwriter's Blues",
#    'release_id': '87cfe963-f297-4c99-84fb-17b6809650a4',
#    'release_group_id': 'f5e3a43f-5c41-4a21-b007-e43f4df68c89',
#    'labels': ['Slash', 'Warner Bros. Records'],
#    'label_ids': ['490afeef-44aa-4bba-b5d7-df875609957f',
#     'c595c289-47ce-4fba-b999-b87503e8cb71'],
#    'release_date': '1994-08-10',
#    'rotation_status': None,
#    'is_local': False,
#    'is_request': False,
#    'is_live': False,
#    'comment': "This 1994 release is a poem Soul Coughing's Mike Doughty dreamed up about L.A. while actually living in New York. It was inspired after a trip out to Huntington Beach the previous summer with his mom - https://lat.ms/3Ab0A6k\n---\nHappy 1994 & 50 years of KEXP! - https://www.kexp.org/50/",
#    'play_type': 'trackplay'},
#   {'id': 3076274,
#    'uri': 'https://api.kexp.org/v2/plays/3076274/',
#    'airdate': '2022-08-10T07:13:07-07:00',
#    'show': 54475,
#    'show_uri': 'https://api.kexp.org/v2/shows/54475/',
#    'image_uri': 'https://ia902203.us.archive.org/3/items/mbid-a1b805e1-c67e-4ef4-a9e3-9fc8c4570467/mbid-a1b805e1-c67e-4ef4-a9e3-9fc8c4570467-31660576774_thumb500.jpg',
#    'thumbnail_uri': 'https://ia802203.us.archive.org/3/items/mbid-a1b805e1-c67e-4ef4-a9e3-9fc8c4570467/mbid-a1b805e1-c67e-4ef4-a9e3-9fc8c4570467-31660576774_thumb250.jpg',
#    'song': 'Bodhisattva Vow',
#    'track_id': '069399c8-7edf-496e-97b7-f8821c2e4251',
#    'recording_id': 'b2dea445-e295-40e3-ab1e-b48c17b9e57c',
#    'artist': 'Beastie Boys',
#    'artist_ids': ['9beb62b2-88db-4cea-801e-162cd344ee53'],
#    'album': 'Ill Communication',
#    'release_id': 'a1b805e1-c67e-4ef4-a9e3-9fc8c4570467',
#    'release_group_id': '1134696c-1078-3c38-bcaa-4ee7c320670a',
#    'labels': ['Capitol Records'],
#    'label_ids': ['abea2d3e-eabf-4480-ab24-9382dd642c73'],
#    'release_date': '1994-08-10',
#    'rotation_status': None,
#    'is_local': False,
#    'is_request': False,
#    'is_live': False,
#    'comment': 'The song was driven primarily by Beastie Boy Adam Yauch (MCA). As a practicing Buddhist, he had taken the Bodhisattva vow, which is a promise to liberate all sentient beings from suffering by practicing the six perfections of giving, moral discipline, patience, effort, concentration, and wisdom. Yauch began his serious study of Buddhism after attending a Dalai Lama lecture in spring 1993, in the midst of recording the Check Your Head album. "The general concept behind the song," Yauch said, "was to take the meaning of Shantideva\'s text, at least on the level that I understood it, and compress it into a modernized, three-verse rhyming song." https://www.songfacts.com/facts/beastie-boys/bodhisattva-vow\n---\nCelebrating the music of 1994 & 50 years of KEXP! - https://www.kexp.org/50/',
#    'play_type': 'trackplay'},
#   {'id': 3076273,
#    'uri': 'https://api.kexp.org/v2/plays/3076273/',
#    'airdate': '2022-08-10T07:09:43-07:00',
#    'show': 54475,
#    'show_uri': 'https://api.kexp.org/v2/shows/54475/',
#    'image_uri': 'https://ia802203.us.archive.org/3/items/mbid-a1b805e1-c67e-4ef4-a9e3-9fc8c4570467/mbid-a1b805e1-c67e-4ef4-a9e3-9fc8c4570467-31660576774_thumb500.jpg',
#    'thumbnail_uri': 'https://ia802203.us.archive.org/3/items/mbid-a1b805e1-c67e-4ef4-a9e3-9fc8c4570467/mbid-a1b805e1-c67e-4ef4-a9e3-9fc8c4570467-31660576774_thumb250.jpg',
#    'song': 'Shambala',
#    'track_id': 'e25e95ef-dbb0-4104-a55d-e74d746f4f99',
#    'recording_id': 'd01df1eb-d6d4-46b6-a358-442a4267b1c3',
#    'artist': 'Beastie Boys',
#    'artist_ids': ['9beb62b2-88db-4cea-801e-162cd344ee53'],
#    'album': 'Ill Communication',
#    'release_id': 'a1b805e1-c67e-4ef4-a9e3-9fc8c4570467',
#    'release_group_id': '1134696c-1078-3c38-bcaa-4ee7c320670a',
#    'labels': ['Capitol Records'],
#    'label_ids': ['abea2d3e-eabf-4480-ab24-9382dd642c73'],
#    'release_date': '1994-08-10',
#    'rotation_status': None,
#    'is_local': False,
#    'is_request': False,
#    'is_live': False,
#    'comment': '"Shambala" is the 18th track on the Beastie Boys Album Ill Communication from 1994.',
#    'play_type': 'trackplay'},
#   {'id': 3076272,
#    'uri': 'https://api.kexp.org/v2/plays/3076272/',
#    'airdate': '2022-08-10T07:05:46-07:00',
#    'show': 54475,
#    'show_uri': 'https://api.kexp.org/v2/shows/54475/',
#    'image_uri': 'https://ia601605.us.archive.org/7/items/mbid-dfd7dcd1-2322-3129-a173-e5510ce0fdf4/mbid-dfd7dcd1-2322-3129-a173-e5510ce0fdf4-16701088935_thumb500.jpg',
#    'thumbnail_uri': 'https://ia801605.us.archive.org/7/items/mbid-dfd7dcd1-2322-3129-a173-e5510ce0fdf4/mbid-dfd7dcd1-2322-3129-a173-e5510ce0fdf4-16701088935_thumb250.jpg',
#    'song': 'I Am Stretched on Your Grave',
#    'track_id': 'ba753171-4d97-3b99-b64c-cf81c60dfe3a',
#    'recording_id': 'fedc888b-683e-4c8e-a643-caefb8535603',
#    'artist': 'Dead Can Dance',
#    'artist_ids': ['ccda046a-2674-4f7d-97e6-f23d6c156432'],
#    'album': 'Toward the Within',
#    'release_id': 'dfd7dcd1-2322-3129-a173-e5510ce0fdf4',
#    'release_group_id': 'aa176d7c-8fdb-3d31-a5a5-f5cc3607d10c',
#    'labels': ['4AD', 'Warner Bros. Records'],
#    'label_ids': ['a539bb1e-f2e1-4b45-9db8-8053841e7503',
#     'c595c289-47ce-4fba-b999-b87503e8cb71'],
#    'release_date': '1994-10-25',
#    'rotation_status': None,
#    'is_local': False,
#    'is_request': False,
#    'is_live': False,
#    'comment': "Toward the Within (1994) is the first official live album of Brendan Perry and Lisa Gerrard's group Dead Can Dance.\nDead Can Dance plans the Paramount Theatre on Monday, March 26 - https://www.deadcandance.com/\n---\nCelebrating the music of 1994 & 50 years of KEXP! - https://www.kexp.org/50/",
#    'play_type': 'trackplay'},
#   {'id': 3076271,
#    'uri': 'https://api.kexp.org/v2/plays/3076271/',
#    'airdate': '2022-08-10T07:01:51-07:00',
#    'show': 54475,
#    'show_uri': 'https://api.kexp.org/v2/shows/54475/',
#    'image_uri': 'https://coverartarchive.org/release/c4ae2add-0c2e-4a2f-ae4e-f79b2da53db6/27473949979-500.jpg',
#    'thumbnail_uri': 'https://coverartarchive.org/release/c4ae2add-0c2e-4a2f-ae4e-f79b2da53db6/27473949979-250.jpg',
#    'song': 'Smells Like Teen Spirit',
#    'track_id': None,
#    'recording_id': '10f0df36-6f0b-48d7-ae29-3573388ada10',
#    'artist': 'The Benzedrine Monks of Santo Domonica',
#    'artist_ids': ['5ffc83be-7f28-4e2a-9be5-4beb096b69db'],
#    'album': 'Chantmania',
#    'release_id': None,
#    'release_group_id': 'a20d24dd-6d09-35fc-b39c-1acf95681736',
#    'labels': [],
#    'label_ids': [],
#    'release_date': '1994-07-12',
#    'rotation_status': None,
#    'is_local': False,
#    'is_request': False,
#    'is_live': False,
#    'comment': "Hey Wednesday, it's time for The Morning Show!\n---\nAs part of KEXP’s 50th anniversary celebration, we’re taking an in-depth look at each year of our history – from 1972 to 2022. This week we are focusing on the music of 1994, like this cover of Smells Like Teen Spirit by The Benzedrine Monks of Santo Domonica.",
#    'play_type': 'trackplay'},
#   {'id': 3076270,
#    'uri': 'https://api.kexp.org/v2/plays/3076270/',
#    'airdate': '2022-08-10T07:00:40-07:00',
#    'show': 54473,
#    'show_uri': 'https://api.kexp.org/v2/shows/54473/',
#    'image_uri': '',
#    'thumbnail_uri': '',
#    'comment': '',
#    'play_type': 'airbreak'}]}

# %%
plays.json()['results'][0]
# Out:
# {'id': 3076290,
#  'uri': 'https://api.kexp.org/v2/plays/3076290/',
#  'airdate': '2022-08-10T07:58:07-07:00',
#  'show': 54475,
#  'show_uri': 'https://api.kexp.org/v2/shows/54475/',
#  'image_uri': '',
#  'thumbnail_uri': '',
#  'comment': '',
#  'play_type': 'airbreak'}

# %%
plays.json()['results'][1]
# Out:
# {'id': 3076289,
#  'uri': 'https://api.kexp.org/v2/plays/3076289/',
#  'airdate': '2022-08-10T07:53:41-07:00',
#  'show': 54475,
#  'show_uri': 'https://api.kexp.org/v2/shows/54475/',
#  'image_uri': 'https://ia600904.us.archive.org/23/items/mbid-8838d557-42df-4ebd-88a4-f74cbc33e8f8/mbid-8838d557-42df-4ebd-88a4-f74cbc33e8f8-22584905643_thumb500.jpg',
#  'thumbnail_uri': 'https://ia800904.us.archive.org/23/items/mbid-8838d557-42df-4ebd-88a4-f74cbc33e8f8/mbid-8838d557-42df-4ebd-88a4-f74cbc33e8f8-22584905643_thumb250.jpg',
#  'song': 'In Circles',
#  'track_id': '6821cd55-295f-3ad0-b507-21784acbb711',
#  'recording_id': '91872a9f-6640-401c-8b9c-4cb8241f3e1e',
#  'artist': 'Sunny Day Real Estate',
#  'artist_ids': ['86b24e8f-a4d9-4c84-83ee-fde0d14ad9fa'],
#  'album': 'Diary',
#  'release_id': '8838d557-42df-4ebd-88a4-f74cbc33e8f8',
#  'release_group_id': '12e88251-2cde-3bea-9cee-2d8c7fe65039',
#  'labels': ['Sub Pop Records'],
#  'label_ids': ['38dc88de-7720-4100-9d5b-3cdc41b0c474'],
#  'release_date': '1994-05-10',
#  'rotation_status': None,
#  'is_local': True,
#  'is_request': False,
#  'is_live': False,
#  'comment': 'Diary is the debut studio album by American rock band Sunny Day Real Estate, released in 1994.\n---\nSunny Day Real Estate will be performing at the Moore Theatre on December 17th & 18th! https://www.sunnyday.realestate/\n---\nCelebrating the music of 1994 & 50 years of KEXP! - https://www.kexp.org/50',
#  'play_type': 'trackplay'}

# %%
https://api.kexp.org/v2/plays/?airdate_after=&airdate_before=&has_comment=&exclude_airbreaks=&show_ids=&host_ids=&song=&song_exact=&artist=&artist_exact=&album=&album_exact=&label=&label_exact=&recording_id=&ordering=

# %%
import urllib

# %%
url = 'https://api.kexp.org/v2/plays/'
params = 'airdate_after=2022-08-10T07:00:00&airdate_before=2022-08-10T08:00:00'
qry = urllib.urlencode(params).replace('%3A', ':')
s = requests.Session()
req = requests.Request(method='GET', url=url)
prep = req.prepare()
prep.url = url + qry
r = s.send(prep)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [34], in <cell line: 3>()
#       1 url = 'https://api.kexp.org/v2/plays/'
#       2 params = 'airdate_after=2022-08-10T07:00:00&airdate_before=2022-08-10T08:00:00'
# ----> 3 qry = urllib.urlencode(params).replace('%3A', ':')
#       4 s = requests.Session()
#       5 req = requests.Request(method='GET', url=url)
#
# AttributeError: module 'urllib' has no attribute 'urlencode'
